# %% [markdown]
# ### Person Occupation Taxonomy
# Map a person's occupations in Wikidata to a standard taxonomy of occupations -- e.g., science fiction writer -> writer. This notebook has two steps: pre-caching a mapping of every occupation value on Wikidata to the taxonomy and then applying that to a Wikidata dump.

# %%
import re
import time

import mwapi
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
import wmfdata

# %%
# !which python
# Out:
# /home/isaacj/.conda/envs/2021-03-18T15.28.24_isaacj/bin/python

# %%
spark = wmfdata.spark.get_session(app_name='pyspark reg; occupations',
                                  type='yarn-regular')  # local, yarn-regular, yarn-large
# Out:
# PySpark executors will use /usr/lib/anaconda-wmf/bin/python3.

# %%
print("Wikidata:")
spark.sql('show partitions wmf.wikidata_item_page_link').show(50, False)

print("\nMediawiki:")
spark.sql("show partitions wmf_raw.mediawiki_project_namespace_map").show(50, False)
# Out:
# Wikidata:
# +-------------------+
# |partition          |
# +-------------------+
# |snapshot=2021-12-13|
# |snapshot=2021-12-20|
# |snapshot=2021-12-27|
# |snapshot=2022-01-03|
# |snapshot=2022-01-10|
# |snapshot=2022-01-17|
# +-------------------+

# %%
wd_snapshot = '2022-01-03'
mw_snapshot = '2021-12'
taxonomy_tablename = 'isaacj.occupation_taxonomy'
data_tablename = 'isaacj.occupation_wikidata'

# Occupations which are overly generic
# Worker, Person, Individual, Researcher, Academic, Official, White-collar worker, Creator, Position, Profession, Group of humans, Organization, Author
PERSON_STOPPOINTS = ['Q327055', 'Q215627', 'Q795052', 'Q1650915', 'Q3400985', 'Q599151', 'Q255274', 'Q2500638', 'Q4164871', 'Q28640', 'Q16334295', 'Q43229']

# the high-level occupation categories we want to map every occupation to
PERSON_CATEGORIES = {
    'Q15253558':'activist',
    'Q19261760':'agricultural worker',
    'Q483501':'artist',
    'Q2066131':'athlete',
    'Q864503':'biologist',
    'Q43845':'businessperson',
    'Q593644':'chemist',
    'Q212238':'civil servant',
    'Q3315492':'clergyperson',
    'Q82594':'computer scientist',
    'Q5322166':'designer',
    'Q11424604':'earth scientist',
    'Q974144':'educator',
    'Q81096':'engineer',
    'Q11974939':'health professional',
    'Q16727193':'humanities scholar',
    'Q1662485':'information professional',
    'Q1930187':'journalist',
    'Q185351':'jurist',
    'Q14467526':'linguist',
    'Q170790':'mathematician',
    'Q15980804':'media professional',
    'Q47064':'military personnel',
    'Q639669':'musician',
    'Q713200':'performing artist',
    'Q169470':'physicist',
    'Q82955':'politician',
    'Q901':'scientist',
    'Q15319501':'social scientist',
    'Q50995749':'sportsperson (non-athlete)',
    'Q56148021':'transportation occupation',
    'Q36180':'writer'
}

# %% [markdown]
# ## Get all potential occupation values

# %%
def querySparql(query):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.queryAndConvert()
    return results['results']['bindings']

# %%
all_occupation_values_query = """
SELECT DISTINCT ?value
WHERE
{
  # ?item wdt:P106 ?value
}
"""

occ_values = [o['value']['value'].split('/')[-1] for o in querySparql(all_occupation_values_query)]
print(f'{len(occ_values)} distinct occupation values.')
# Out:
# 17162 distinct occupation values.

# %%
class OccupationTaxonomy():
    
    def __init__(self, base_occupations, stoppoints, endpoints, maxiter=8):
        self.occupation_categories = endpoints
        self.person_taxonomy = {q:set([q]) for q in self.occupation_categories}  # eventual mapping of Occupation QID -> Stop-point Label
        for sp in stoppoints:  # too generic -- doesn't map to anything
            self.person_taxonomy[sp] = set()
        self.session = mwapi.Session('https://www.wikidata.org', user_agent='Isaac (WMF); occupation taxonomy')
        self.maxiter = maxiter
        self.build_person_taxonomy(base_occupations)
        
    def build_person_taxonomy(self, base_occupations):
        for i, occ in enumerate(base_occupations, start=1):
            try:
                self.leaf_to_roots(occ, 0)
            except Exception:
                print(f"Failed for {occ}")
                continue
            if i % 100 == 0:
                print(f'{i} occupations processed -- taxonomy now has {len(self.person_taxonomy)} entries.')

    def leaf_to_roots(self, qid, iter_num=0):
        # Uses subclass-of (P279) as that seems optimal for occupation. Potentially could be tweaked to include other properties.
        if qid in self.person_taxonomy:  # already found
            return
        elif iter_num == self.maxiter:  # hit max-depth, bummer but stop search
            return
        elif qid not in self.person_taxonomy:  # make sure qid has entry in taxonomy
            self.person_taxonomy[qid] = set()
        
        # no quick solution -- get super-classes for QID and recurse from there
        scs = self.get_superclasses(qid)
        for sc in scs:
            # not found: process superclass
            if sc not in self.person_taxonomy:
                self.leaf_to_roots(sc, iter_num+1)            
            # sc in taxonomy already or was just updated: update taxonomy
            if sc in self.person_taxonomy:
                self.person_taxonomy[qid].update(self.person_taxonomy[sc])                
                

    def get_superclasses(self, qid):
        # e.g., input qid for chemical engineer -> ['engineer', 'chemist', 'engineering professionals'] (though represented as QIDs)
        try:
            result = self.session.get(
                action="wbgetclaims",
                entity=qid,
                property='P279',
                format='json',
                formatversion=2
            )
            scs = []
            for sc in result['claims'].get('P279', []):
                if sc.get('mainsnak', {}).get('datatype') == 'wikibase-item':
                    try:
                        scs.append(sc['mainsnak']['datavalue']['value']['id'])
                    except KeyError:
                        continue
        except Exception:
            scs = []
        time.sleep(0.25)
        return scs
    
    def print_taxonomy(self):
        occurences = {}
        for q in self.person_taxonomy:
            print(f'{q}:\t{[self.occupation_categories[o] for o in self.person_taxonomy[q]]}')
            for o in self.person_taxonomy[q]:
                occurences[o] = occurences.get(o, 0) + 1
        print("\nStats of occurrences:")
        sorted_occs = sorted(occurences, key=occurences.get, reverse=True)
        for o in sorted_occs:
            print(f'{self.occupation_categories.get(o, o)}:\t{occurences[o]} occurences.')

# %%
ot = OccupationTaxonomy(occ_values, PERSON_STOPPOINTS, PERSON_CATEGORIES)

# %%
tax_df = []
for o,t in ot.person_taxonomy.items():
    if len(t) > 0:
        for q in t:
            tax_df.append((o, ot.occupation_categories[q]))
tax_df = pd.DataFrame(tax_df, columns=['qid', 'root_occupation'])
tax_df
# Out:
#              qid      root_occupation
# 0      Q15253558             activist
# 1      Q19261760  agricultural worker
# 2        Q483501               artist
# 3       Q2066131              athlete
# 4        Q864503            biologist
# ...          ...                  ...
# 7198  Q110776779   humanities scholar
# 7199  Q110779725             educator
# 7200  Q110779725       businessperson
# 7201  Q110779750  health professional
# 7202  Q110782826   computer scientist
#
# [7203 rows x 2 columns]

# %%
spark.createDataFrame(tax_df).createOrReplaceTempView('person_taxonomy')
spark.sql('''
SELECT
  root_occupation,
  count(distinct(qid)) as num_leaves
FROM person_taxonomy
GROUP BY
  root_occupation
ORDER BY
  num_leaves DESC''').show(50, False)

# %%
do_execute = True
create_table_query = f"""
    CREATE TABLE IF NOT EXISTS {taxonomy_tablename} (
        qid              STRING  COMMENT 'Potential value for occupation',
        root_occupation  STRING  COMMENT 'High-level occupation that occupation value maps up to'
    )
    """

if do_execute:
    spark.sql(create_table_query)

# %%
spark.sql(f'''
INSERT OVERWRITE TABLE {taxonomy_tablename}
SELECT
  qid,
  root_occupation
FROM person_taxonomy
''')

spark.sql(f'select root_occupation, count(distinct(qid)) as num_leaves from {taxonomy_tablename} group by root_occupation order by num_leaves DESC').show(50, False)
# Out:
# +--------------------------+----------+
# |root_occupation           |num_leaves|
# +--------------------------+----------+
# |politician                |614       |
# |artist                    |512       |
# |civil servant             |488       |
# |businessperson            |432       |
# |musician                  |399       |
# |health professional       |377       |
# |athlete                   |353       |
# |humanities scholar        |331       |
# |military personnel        |331       |
# |clergyperson              |266       |
# |scientist                 |265       |
# |educator                  |258       |
# |biologist                 |243       |
# |jurist                    |215       |
# |performing artist         |211       |
# |writer                    |208       |
# |sportsperson (non-athlete)|205       |
# |engineer                  |205       |
# |media professional        |177       |
# |activist                  |160       |
# |social scientist          |159       |
# |designer                  |131       |
# |transportation occupation |128       |
# |earth scientist           |105       |
# |agricultural worker       |91        |
# |journalist                |80        |
# |linguist                  |58        |
# |information professional  |53        |
# |physicist                 |42        |
# |mathematician             |40        |
# |chemist                   |40        |
# |computer scientist        |26        |
# +--------------------------+----------+

# %% [markdown]
# ## Build Dataset

# %%
do_execute = True
create_table_query = f"""
    CREATE TABLE IF NOT EXISTS {data_tablename} (
        item_id          STRING  COMMENT 'Wikidata ID',
        root_occupation  STRING  COMMENT 'High-level occupation that occupation value maps up to'
    )
    """

if do_execute:
    spark.sql(create_table_query)

# %%
# value info in wikidata entity table (https://wikitech.wikimedia.org/wiki/Analytics/Data_Lake/Edits/Wikidata_entity)
# is a string as opposed to struct (because it has a variable schema)
# this UDF extracts the QID value (or null if doesn't exist)
def getValue(obj):
    try:
        d =  eval(obj)
        return d.get('id')
    except Exception:
        return None
    
spark.udf.register('getValue', getValue, 'string')
# Out:
# <function __main__.getValue(obj)>

# %%
print_for_hive = False
do_execute = True

query = f"""
WITH wikipedia_projects AS (
    SELECT DISTINCT
      dbname
    FROM wmf_raw.mediawiki_project_namespace_map
    WHERE
      snapshot = '{mw_snapshot}'
      AND hostname LIKE '%wikipedia%'
),
relevant_qids AS (
    SELECT DISTINCT
      item_id
    FROM wmf.wikidata_item_page_link wd
    INNER JOIN wikipedia_projects wp
      ON (wd.wiki_db = wp.dbname)
    WHERE
      snapshot = '{wd_snapshot}'
      AND page_namespace = 0
),
exploded_statements AS (
    SELECT
      id as item_id,
      explode(claims) as claim
    FROM wmf.wikidata_entity w
    INNER JOIN relevant_qids q
      ON (w.id = q.item_id)
    WHERE
      snapshot = '{wd_snapshot}'
),
relevant_statements AS (
    SELECT
      item_id,
      getValue(claim.mainSnak.dataValue.value) as value
    FROM exploded_statements
    WHERE
      claim.mainSnak.property = 'P106'
)
INSERT OVERWRITE TABLE {data_tablename}
SELECT
  item_id,
  root_occupation
FROM relevant_statements s
INNER JOIN {taxonomy_tablename} t
  ON (s.value = t.qid)
"""

if print_for_hive:
    print(re.sub(' +', ' ', re.sub('\n', ' ', query)).strip())
else:
    print(query)

if do_execute:
    result = spark.sql(query)
# Out:
# WITH wikipedia_projects AS (
#     SELECT DISTINCT
#       dbname
#     FROM wmf_raw.mediawiki_project_namespace_map
#     WHERE
#       snapshot = '2021-12'
#       AND hostname LIKE '%wikipedia%'
# ),
# relevant_qids AS (
#     SELECT DISTINCT
#       item_id
#     FROM wmf.wikidata_item_page_link wd
#     INNER JOIN wikipedia_projects wp
#       ON (wd.wiki_db = wp.dbname)
#     WHERE
#       snapshot = '2022-01-03'
#       AND page_namespace = 0
# ),
# exploded_statements AS (
#     SELECT
#       id as item_id,
#       explode(claims) as claim
#     FROM wmf.wikidata_entity w
#     INNER JOIN relevant_qids q
#       ON (w.id = q.item_id)
#     WHERE
#       snapshot = '2022-01-03'
# ),
# relevant_statements AS (
#     SELECT
#       item_id,
#       getValue(claim.mainSnak.dataValue.value) as value
#     FROM exploded_statements
#     WHERE
#       claim.mainSnak.property = 'P106'
# )
# INSERT OVERWRITE TABLE isaacj.occupation_wikidata
# SELECT
#   item_id,
#   root_occupation
# FROM relevant_statements s
# INNER JOIN isaacj.occupation_taxonomy t
#   ON (s.value = t.qid)

# %%
spark.sql(f'SELECT root_occupation, COUNT(1) AS num_rows, COUNT(DISTINCT(qid)) AS num_items FROM {data_tablename} GROUP BY root_occupation ORDER BY num_items DESC').show(100, False)
# Out:
# +--------------------------+--------+---------+
# |root_occupation           |num_rows|num_items|
# +--------------------------+--------+---------+
# |athlete                   |890148  |851553   |
# |politician                |571663  |563141   |
# |writer                    |490914  |373651   |
# |artist                    |459051  |352631   |
# |performing artist         |467580  |321120   |
# |musician                  |422295  |270888   |
# |businessperson            |282655  |267607   |
# |educator                  |178171  |170680   |
# |humanities scholar        |189215  |164500   |
# |military personnel        |155565  |149702   |
# |media professional        |181579  |147408   |
# |journalist                |139273  |132188   |
# |jurist                    |143297  |120415   |
# |sportsperson (non-athlete)|109498  |101627   |
# |civil servant             |100170  |97637    |
# |social scientist          |96400   |88838    |
# |health professional       |99636   |86907    |
# |clergyperson              |91696   |84494    |
# |scientist                 |76054   |72332    |
# |designer                  |74969   |70153    |
# |engineer                  |67935   |60620    |
# |activist                  |57088   |54018    |
# |biologist                 |65831   |51504    |
# |linguist                  |53918   |49285    |
# |transportation occupation |36006   |34784    |
# |mathematician             |24271   |23217    |
# |earth scientist           |25065   |22131    |
# |physicist                 |24207   |22050    |
# |chemist                   |20838   |20024    |
# |agricultural worker       |14027   |13827    |
# |information professional  |11635   |11138    |
# |computer scientist        |8342    |7988     |
# +--------------------------+--------+---------+

# %%
# studs terkel
spark.sql(f'SELECT * FROM {data_tablename} WHERE qid = "Q529276"').show(100, False)
# Out:
# +-------+------------------+
# |qid    |root_occupation   |
# +-------+------------------+
# |Q529276|journalist        |
# |Q529276|humanities scholar|
# |Q529276|media professional|
# |Q529276|writer            |
# |Q529276|writer            |
# |Q529276|jurist            |
# |Q529276|journalist        |
# |Q529276|performing artist |
# +-------+------------------+

# %%
# out of order but output too large so put at end of notebook
ot = OccupationTaxonomy(occ_values, PERSON_STOPPOINTS, PERSON_CATEGORIES)
ot.print_taxonomy()
# Out:
# 100 occupations processed -- taxonomy now has 590 entries.
# 200 occupations processed -- taxonomy now has 945 entries.
# 300 occupations processed -- taxonomy now has 1278 entries.
# 400 occupations processed -- taxonomy now has 1638 entries.
# 500 occupations processed -- taxonomy now has 1935 entries.
# 600 occupations processed -- taxonomy now has 2177 entries.
# 700 occupations processed -- taxonomy now has 2364 entries.
# 800 occupations processed -- taxonomy now has 2600 entries.
# 900 occupations processed -- taxonomy now has 2792 entries.
# 1000 occupations processed -- taxonomy now has 3018 entries.
# 1100 occupations processed -- taxonomy now has 3213 entries.
# 1200 occupations processed -- taxonomy now has 3403 entries.
# 1300 occupations processed -- taxonomy now has 3578 entries.
# 1400 occupations processed -- taxonomy now has 3743 entries.
# 1500 occupations processed -- taxonomy now has 3909 entries.
# 1600 occupations processed -- taxonomy now has 4082 entries.
# 1700 occupations processed -- taxonomy now has 4246 entries.
# 1800 occupations processed -- taxonomy now has 4433 entries.
# 1900 occupations processed -- taxonomy now has 4582 entries.
# 2000 occupations processed -- taxonomy now has 4745 entries.
# 2100 occupations processed -- taxonomy now has 4908 entries.
# 2200 occupations processed -- taxonomy now has 5083 entries.
# 2300 occupations processed -- taxonomy now has 5242 entries.
# 2400 occupations processed -- taxonomy now has 5375 entries.
# 2500 occupations processed -- taxonomy now has 5532 entries.
# 2600 occupations processed -- taxonomy now has 5657 entries.
# 2700 occupations processed -- taxonomy now has 5813 entries.
# 2800 occupations processed -- taxonomy now has 5951 entries.
# 2900 occupations processed -- taxonomy now has 6099 entries.
# 3000 occupations processed -- taxonomy now has 6230 entries.
# 3100 occupations processed -- taxonomy now has 6401 entries.
# 3200 occupations processed -- taxonomy now has 6528 entries.
# 3300 occupations processed -- taxonomy now has 6652 entries.
# 3400 occupations processed -- taxonomy now has 6780 entries.
# 3500 occupations processed -- taxonomy now has 6930 entries.
# 3600 occupations processed -- taxonomy now has 7053 entries.
# 3700 occupations processed -- taxonomy now has 7213 entries.
# 3800 occupations processed -- taxonomy now has 7316 entries.
# 3900 occupations processed -- taxonomy now has 7453 entries.
# 4000 occupations processed -- taxonomy now has 7562 entries.
# 4100 occupations processed -- taxonomy now has 7698 entries.
# 4200 occupations processed -- taxonomy now has 7832 entries.
# 4300 occupations processed -- taxonomy now has 7982 entries.
# 4400 occupations processed -- taxonomy now has 8095 entries.
# 4500 occupations processed -- taxonomy now has 8218 entries.
# 4600 occupations processed -- taxonomy now has 8342 entries.
# 4700 occupations processed -- taxonomy now has 8456 entries.
# 4800 occupations processed -- taxonomy now has 8575 entries.
# 4900 occupations processed -- taxonomy now has 8691 entries.
# 5000 occupations processed -- taxonomy now has 8818 entries.
# 5100 occupations processed -- taxonomy now has 8923 entries.
# 5200 occupations processed -- taxonomy now has 9034 entries.
# 5300 occupations processed -- taxonomy now has 9144 entries.
# 5400 occupations processed -- taxonomy now has 9258 entries.
# 5500 occupations processed -- taxonomy now has 9368 entries.
# 5600 occupations processed -- taxonomy now has 9486 entries.
# 5700 occupations processed -- taxonomy now has 9595 entries.
# 5800 occupations processed -- taxonomy now has 9707 entries.
# 5900 occupations processed -- taxonomy now has 9814 entries.
# 6000 occupations processed -- taxonomy now has 9926 entries.
# 6100 occupations processed -- taxonomy now has 10027 entries.
# 6200 occupations processed -- taxonomy now has 10150 entries.
# 6300 occupations processed -- taxonomy now has 10257 entries.
# 6400 occupations processed -- taxonomy now has 10360 entries.
# 6500 occupations processed -- taxonomy now has 10466 entries.
# 6600 occupations processed -- taxonomy now has 10573 entries.
# 6700 occupations processed -- taxonomy now has 10677 entries.
# 6800 occupations processed -- taxonomy now has 10796 entries.
# 6900 occupations processed -- taxonomy now has 10901 entries.
# 7000 occupations processed -- taxonomy now has 11018 entries.
# 7100 occupations processed -- taxonomy now has 11122 entries.
# 7200 occupations processed -- taxonomy now has 11219 entries.
# 7300 occupations processed -- taxonomy now has 11319 entries.
# 7400 occupations processed -- taxonomy now has 11421 entries.
# 7500 occupations processed -- taxonomy now has 11530 entries.
# 7600 occupations processed -- taxonomy now has 11626 entries.
# 7700 occupations processed -- taxonomy now has 11731 entries.
# 7800 occupations processed -- taxonomy now has 11835 entries.
# 7900 occupations processed -- taxonomy now has 11933 entries.
# 8000 occupations processed -- taxonomy now has 12037 entries.
# 8100 occupations processed -- taxonomy now has 12134 entries.
# 8200 occupations processed -- taxonomy now has 12235 entries.
# 8300 occupations processed -- taxonomy now has 12344 entries.
# 8400 occupations processed -- taxonomy now has 12451 entries.
# 8500 occupations processed -- taxonomy now has 12572 entries.
# 8600 occupations processed -- taxonomy now has 12664 entries.
# 8700 occupations processed -- taxonomy now has 12767 entries.
# 8800 occupations processed -- taxonomy now has 12864 entries.
# 8900 occupations processed -- taxonomy now has 12967 entries.
# 9000 occupations processed -- taxonomy now has 13062 entries.
# 9100 occupations processed -- taxonomy now has 13174 entries.
# 9200 occupations processed -- taxonomy now has 13280 entries.
# 9300 occupations processed -- taxonomy now has 13387 entries.
# 9400 occupations processed -- taxonomy now has 13492 entries.
# 9500 occupations processed -- taxonomy now has 13586 entries.
# 9600 occupations processed -- taxonomy now has 13686 entries.
# 9700 occupations processed -- taxonomy now has 13783 entries.
# 9800 occupations processed -- taxonomy now has 13882 entries.
# 9900 occupations processed -- taxonomy now has 14000 entries.
# 10000 occupations processed -- taxonomy now has 14093 entries.
# 10100 occupations processed -- taxonomy now has 14192 entries.
# 10200 occupations processed -- taxonomy now has 14277 entries.
# 10300 occupations processed -- taxonomy now has 14371 entries.
# 10400 occupations processed -- taxonomy now has 14466 entries.
# 10500 occupations processed -- taxonomy now has 14553 entries.
# 10600 occupations processed -- taxonomy now has 14648 entries.
# 10700 occupations processed -- taxonomy now has 14748 entries.
# 10800 occupations processed -- taxonomy now has 14846 entries.
# 10900 occupations processed -- taxonomy now has 14939 entries.
# 11000 occupations processed -- taxonomy now has 15037 entries.
# 11100 occupations processed -- taxonomy now has 15135 entries.
# 11200 occupations processed -- taxonomy now has 15242 entries.
# 11300 occupations processed -- taxonomy now has 15338 entries.
# 11400 occupations processed -- taxonomy now has 15436 entries.
# 11500 occupations processed -- taxonomy now has 15541 entries.
# 11600 occupations processed -- taxonomy now has 15631 entries.
# 11700 occupations processed -- taxonomy now has 15730 entries.
# 11800 occupations processed -- taxonomy now has 15832 entries.
# 11900 occupations processed -- taxonomy now has 15932 entries.
# 12000 occupations processed -- taxonomy now has 16033 entries.
# 12100 occupations processed -- taxonomy now has 16138 entries.
# 12200 occupations processed -- taxonomy now has 16236 entries.
# 12300 occupations processed -- taxonomy now has 16335 entries.
# 12400 occupations processed -- taxonomy now has 16432 entries.
# 12500 occupations processed -- taxonomy now has 16528 entries.
# 12600 occupations processed -- taxonomy now has 16631 entries.
# 12700 occupations processed -- taxonomy now has 16729 entries.
# 12800 occupations processed -- taxonomy now has 16831 entries.
# 12900 occupations processed -- taxonomy now has 16940 entries.
# 13000 occupations processed -- taxonomy now has 17042 entries.
# 13100 occupations processed -- taxonomy now has 17142 entries.
# 13200 occupations processed -- taxonomy now has 17241 entries.
# 13300 occupations processed -- taxonomy now has 17343 entries.
# 13400 occupations processed -- taxonomy now has 17445 entries.
# 13500 occupations processed -- taxonomy now has 17542 entries.
# 13600 occupations processed -- taxonomy now has 17638 entries.
# 13700 occupations processed -- taxonomy now has 17746 entries.
# 13800 occupations processed -- taxonomy now has 17845 entries.
# 13900 occupations processed -- taxonomy now has 17949 entries.
# 14000 occupations processed -- taxonomy now has 18045 entries.
# 14100 occupations processed -- taxonomy now has 18149 entries.
# 14200 occupations processed -- taxonomy now has 18240 entries.
# 14300 occupations processed -- taxonomy now has 18339 entries.
# 14400 occupations processed -- taxonomy now has 18443 entries.
# 14500 occupations processed -- taxonomy now has 18547 entries.
# 14600 occupations processed -- taxonomy now has 18645 entries.
# 14700 occupations processed -- taxonomy now has 18749 entries.
# 14800 occupations processed -- taxonomy now has 18849 entries.
# 14900 occupations processed -- taxonomy now has 18944 entries.
# 15000 occupations processed -- taxonomy now has 19037 entries.
# 15100 occupations processed -- taxonomy now has 19140 entries.
# 15200 occupations processed -- taxonomy now has 19245 entries.
# 15300 occupations processed -- taxonomy now has 19344 entries.
# 15400 occupations processed -- taxonomy now has 19448 entries.
# 15500 occupations processed -- taxonomy now has 19542 entries.
# 15600 occupations processed -- taxonomy now has 19639 entries.
# 15700 occupations processed -- taxonomy now has 19737 entries.
# 15800 occupations processed -- taxonomy now has 19829 entries.
# 15900 occupations processed -- taxonomy now has 19929 entries.
# 16000 occupations processed -- taxonomy now has 20034 entries.
# 16100 occupations processed -- taxonomy now has 20138 entries.
# 16200 occupations processed -- taxonomy now has 20241 entries.
# 16300 occupations processed -- taxonomy now has 20336 entries.
# 16400 occupations processed -- taxonomy now has 20432 entries.
# 16500 occupations processed -- taxonomy now has 20536 entries.
# 16600 occupations processed -- taxonomy now has 20636 entries.
# 16700 occupations processed -- taxonomy now has 20736 entries.
# 16800 occupations processed -- taxonomy now has 20836 entries.
# 16900 occupations processed -- taxonomy now has 20936 entries.
# 17000 occupations processed -- taxonomy now has 21036 entries.
# 17100 occupations processed -- taxonomy now has 21136 entries.
# Q15253558:	['activist']
# Q19261760:	['agricultural worker']
# Q483501:	['artist']
# Q2066131:	['athlete']
# Q864503:	['biologist']
# Q43845:	['businessperson']
# Q593644:	['chemist']
# Q212238:	['civil servant']
# Q3315492:	['clergyperson']
# Q82594:	['computer scientist']
# Q5322166:	['designer']
# Q11424604:	['earth scientist']
# Q974144:	['educator']
# Q81096:	['engineer']
# Q11974939:	['health professional']
# Q16727193:	['humanities scholar']
# Q1662485:	['information professional']
# Q1930187:	['journalist']
# Q185351:	['jurist']
# Q14467526:	['linguist']
# Q170790:	['mathematician']
# Q15980804:	['media professional']
# Q47064:	['military personnel']
# Q639669:	['musician']
# Q713200:	['performing artist']
# Q169470:	['physicist']
# Q82955:	['politician']
# Q901:	['scientist']
# Q15319501:	['social scientist']
# Q50995749:	['sportsperson (non-athlete)']
# Q56148021:	['transportation occupation']
# Q36180:	['writer']
# Q327055:	[]
# Q215627:	[]
# Q795052:	[]
# Q1650915:	[]
# Q3400985:	[]
# Q599151:	[]
# Q255274:	[]
# Q2500638:	[]
# Q4164871:	[]
# Q28640:	[]
# Q16334295:	[]
# Q43229:	[]
# Q31:	[]
# Q41:	[]
# Q65:	[]
# Q75:	[]
# Q1068715:	[]
# Q1900326:	[]
# Q58778:	[]
# Q6671777:	[]
# Q99527517:	[]
# Q35120:	[]
# Q577764:	[]
# Q106865223:	[]
# Q16686448:	[]
# Q488383:	[]
# Q386724:	[]
# Q15401930:	[]
# Q1150771:	[]
# Q121359:	[]
# Q28877:	[]
# Q2897903:	[]
# Q58415929:	[]
# Q151885:	[]
# Q2145290:	[]
# Q4393498:	[]
# Q930933:	[]
# Q7184903:	[]
# Q7048977:	[]
# Q1347367:	[]
# Q1207505:	[]
# Q937228:	[]
# Q116:	['politician']
# Q2304859:	['politician']
# Q1097498:	['politician']
# Q15296531:	[]
# Q372436:	['politician']
# Q1251441:	[]
# Q48352:	['politician']
# Q294414:	[]
# Q130:	[]
# Q819073:	[]
# Q41825:	[]
# Q573:	[]
# Q186081:	[]
# Q26907166:	[]
# Q1445650:	[]
# Q15275719:	[]
# Q1656682:	[]
# Q1190554:	[]
# Q12044624:	[]
# Q67518233:	[]
# Q67518978:	[]
# Q3249551:	[]
# Q1150070:	[]
# Q20937557:	[]
# Q16887380:	[]
# Q14795564:	[]
# Q134:	[]
# Q55386374:	[]
# Q208440:	[]
# Q3449901:	[]
# Q17638008:	[]
# Q223557:	[]
# Q4406616:	[]
# Q1454986:	[]
# Q30060700:	[]
# Q35459920:	[]
# Q2424752:	[]
# Q190:	[]
# Q178885:	[]
# Q15619164:	[]
# Q830077:	[]
# Q103940464:	[]
# Q23958946:	[]
# Q28855038:	[]
# Q30060629:	[]
# Q18706315:	[]
# Q4271324:	[]
# Q24334685:	[]
# Q21070598:	[]
# Q18336849:	[]
# Q635155:	[]
# Q4356623:	[]
# Q191:	[]
# Q217:	[]
# Q289:	[]
# Q15078788:	[]
# Q11033:	[]
# Q340169:	[]
# Q12894677:	[]
# Q4026292:	[]
# Q2574811:	[]
# Q31464082:	[]
# Q286583:	[]
# Q8205328:	[]
# Q8148:	[]
# Q1914636:	[]
# Q17537576:	[]
# Q15621286:	[]
# Q121182:	[]
# Q3972943:	[]
# Q268592:	[]
# Q11024:	[]
# Q921513:	[]
# Q2990593:	[]
# Q9332:	[]
# Q2996394:	[]
# Q22294683:	[]
# Q22269697:	[]
# Q6031064:	[]
# Q23009552:	[]
# Q23009675:	[]
# Q52948:	[]
# Q1474334:	[]
# Q29584328:	[]
# Q1256657:	[]
# Q732298:	[]
# Q291:	[]
# Q309:	[]
# Q4330518:	[]
# Q5067949:	[]
# Q333:	[]
# Q14632398:	[]
# Q7991:	[]
# Q336:	[]
# Q110402795:	[]
# Q28813620:	[]
# Q9081:	[]
# Q1048607:	[]
# Q34394:	[]
# Q104127086:	[]
# Q11028:	[]
# Q12488383:	[]
# Q475023:	[]
# Q349:	[]
# Q747883:	[]
# Q61788060:	[]
# Q3769299:	[]
# Q6666023:	[]
# Q79782:	[]
# Q17320256:	[]
# Q1293220:	[]
# Q16722960:	[]
# Q17988854:	[]
# Q193514:	[]
# Q355:	[]
# Q362:	[]
# Q366:	[]
# Q1456832:	[]
# Q3537603:	[]
# Q567555:	[]
# Q849149:	[]
# Q203066:	[]
# Q36161:	[]
# Q217594:	[]
# Q5469988:	[]
# Q246672:	[]
# Q864377:	[]
# Q29896155:	[]
# Q55091441:	[]
# Q2995644:	[]
# Q10862449:	[]
# Q104493:	[]
# Q21170479:	[]
# Q395:	[]
# Q816264:	[]
# Q413:	[]
# Q418:	[]
# Q1472062:	[]
# Q420:	[]
# Q431:	[]
# Q441:	[]
# Q467:	[]
# Q80994:	[]
# Q7239:	[]
# Q27043950:	[]
# Q53617489:	[]
# Q29651224:	[]
# Q851990:	[]
# Q874405:	[]
# Q7887142:	[]
# Q2198779:	[]
# Q84048852:	[]
# Q43445:	[]
# Q19088:	[]
# Q5:	[]
# Q154954:	[]
# Q3778211:	[]
# Q26720107:	[]
# Q24229398:	[]
# Q164509:	[]
# Q72638:	[]
# Q159344:	[]
# Q15978631:	[]
# Q482:	[]
# Q7725634:	[]
# Q47461344:	[]
# Q838948:	[]
# Q18593264:	[]
# Q1318295:	[]
# Q514:	[]
# Q11190:	[]
# Q843601:	[]
# Q28797:	[]
# Q521:	[]
# Q542:	[]
# Q212434:	[]
# Q51031626:	[]
# Q13406554:	[]
# Q476300:	[]
# Q15900616:	[]
# Q18608583:	[]
# Q11047409:	[]
# Q571:	[]
# Q49848:	[]
# Q234460:	[]
# Q107435521:	[]
# Q184754:	[]
# Q37866906:	[]
# Q1554231:	[]
# Q732577:	[]
# Q2342494:	[]
# Q592:	[]
# Q17884:	[]
# Q5110203:	[]
# Q1230584:	[]
# Q21146257:	[]
# Q16889133:	[]
# Q589656:	[]
# Q30103:	[]
# Q110266417:	[]
# Q638:	[]
# Q735:	[]
# Q2018526:	[]
# Q80083:	[]
# Q184872:	[]
# Q451967:	[]
# Q173799:	[]
# Q11461:	[]
# Q3882459:	[]
# Q25498967:	[]
# Q1132631:	[]
# Q37172:	[]
# Q170475:	[]
# Q626707:	[]
# Q649:	[]
# Q676:	[]
# Q718:	[]
# Q287618:	[]
# Q11410:	[]
# Q1150958:	[]
# Q1150710:	[]
# Q573573:	[]
# Q12811949:	[]
# Q1188693:	[]
# Q31629:	[]
# Q50843134:	[]
# Q23807345:	[]
# Q2755547:	[]
# Q729:	[]
# Q748:	[]
# Q1651597:	[]
# Q9174:	[]
# Q5390013:	[]
# Q7257:	[]
# Q48324:	[]
# Q55979391:	[]
# Q49447:	[]
# Q12558574:	[]
# Q595523:	[]
# Q71966963:	[]
# Q3702971:	[]
# Q37787614:	[]
# Q61151961:	[]
# Q42848:	[]
# Q82821:	[]
# Q251777:	[]
# Q367293:	[]
# Q53001749:	[]
# Q794:	[]
# Q847:	[]
# Q877517:	[]
# Q2426135:	[]
# Q866:	[]
# Q918:	[]
# Q998:	[]
# Q7569:	[]
# Q1516282:	[]
# Q1004:	[]
# Q4502142:	[]
# Q7452501:	[]
# Q1033:	[]
# Q1065:	[]
# Q484652:	[]
# Q1069:	[]
# Q8008:	[]
# Q1071:	[]
# Q1075:	[]
# Q40890790:	[]
# Q9128:	[]
# Q11386:	[]
# Q14506045:	[]
# Q1246:	[]
# Q1293:	[]
# Q131436:	[]
# Q3244175:	[]
# Q14947863:	[]
# Q17351672:	[]
# Q1344:	[]
# Q58483083:	[]
# Q105543609:	[]
# Q207628:	[]
# Q2188189:	[]
# Q25379:	[]
# Q25372:	[]
# Q8242:	[]
# Q110013395:	[]
# Q17538722:	[]
# Q7777494:	[]
# Q107021951:	[]
# Q107736421:	[]
# Q61340552:	[]
# Q26897135:	[]
# Q9730:	[]
# Q1583807:	[]
# Q1367:	[]
# Q110551885:	[]
# Q110551902:	[]
# Q1420:	[]
# Q752870:	[]
# Q15618781:	[]
# Q1301433:	[]
# Q42889:	[]
# Q1408229:	[]
# Q1485500:	[]
# Q337060:	[]
# Q11019:	[]
# Q39546:	[]
# Q10273457:	[]
# Q35825432:	[]
# Q1183543:	[]
# Q987767:	[]
# Q9158768:	[]
# Q106839123:	[]
# Q1515493:	[]
# Q12060681:	[]
# Q1439:	[]
# Q1455:	[]
# Q1622659:	[]
# Q216048:	[]
# Q4438147:	[]
# Q1487:	['computer scientist']
# Q1617:	[]
# Q3361977:	[]
# Q11051:	[]
# Q12600937:	[]
# Q2397881:	[]
# Q10979187:	[]
# Q33577:	[]
# Q33514:	[]
# Q15609389:	[]
# Q1734:	[]
# Q1741:	[]
# Q1754:	[]
# Q1799:	[]
# Q1854:	[]
# Q1860:	[]
# Q1346342:	[]
# Q5329170:	[]
# Q26721:	[]
# Q21200:	[]
# Q19860:	[]
# Q771861:	[]
# Q276314:	[]
# Q30134:	[]
# Q1889:	[]
# Q202875:	[]
# Q131395:	[]
# Q17584038:	[]
# Q3685487:	[]
# Q1066689:	[]
# Q7157572:	[]
# Q1194317:	[]
# Q1640893:	[]
# Q2920921:	[]
# Q338754:	[]
# Q1544281:	[]
# Q334401:	[]
# Q29017603:	[]
# Q18340964:	[]
# Q1783823:	[]
# Q309100:	[]
# Q1930:	[]
# Q2009:	[]
# Q2079:	[]
# Q2329:	[]
# Q2346:	[]
# Q2475:	[]
# Q2539:	[]
# Q21198:	[]
# Q13420675:	[]
# Q11660:	[]
# Q8366:	[]
# Q41689629:	[]
# Q2695280:	[]
# Q2736:	[]
# Q1081491:	[]
# Q2743:	[]
# Q2431196:	[]
# Q194980:	[]
# Q106213450:	[]
# Q1370345:	[]
# Q11635:	[]
# Q184485:	[]
# Q43099500:	[]
# Q2868:	[]
# Q2915:	[]
# Q11748378:	[]
# Q830:	[]
# Q57814795:	[]
# Q57812611:	[]
# Q57812559:	[]
# Q16390140:	[]
# Q622852:	[]
# Q1797813:	[]
# Q3609:	[]
# Q2215841:	[]
# Q53121:	[]
# Q334166:	[]
# Q7339484:	[]
# Q3616:	[]
# Q3914:	[]
# Q2385804:	[]
# Q5341295:	[]
# Q2169973:	[]
# Q13420330:	[]
# Q6770826:	[]
# Q1415187:	[]
# Q3930:	[]
# Q4290:	[]
# Q1369832:	[]
# Q601401:	[]
# Q3380760:	[]
# Q1166072:	[]
# Q10954253:	[]
# Q4482:	[]
# Q3059502:	[]
# Q190539:	[]
# Q3622126:	[]
# Q52943:	[]
# Q63248011:	[]
# Q213051:	[]
# Q1660187:	[]
# Q165650:	[]
# Q14623843:	[]
# Q4508:	[]
# Q781132:	[]
# Q176799:	[]
# Q9261468:	[]
# Q17149090:	[]
# Q15627509:	[]
# Q20749395:	[]
# Q4539:	[]
# Q783794:	[]
# Q815823:	[]
# Q1979154:	[]
# Q41719:	[]
# Q108163:	[]
# Q474328:	[]
# Q41796:	[]
# Q1786828:	[]
# Q15916540:	[]
# Q9380010:	[]
# Q321703:	[]
# Q4543:	[]
# Q12045711:	[]
# Q4572:	[]
# Q2292993:	[]
# Q185698:	[]
# Q217602:	[]
# Q21004260:	[]
# Q104637332:	[]
# Q4618:	[]
# Q288514:	[]
# Q464980:	[]
# Q1030034:	[]
# Q3152824:	[]
# Q178706:	[]
# Q294440:	[]
# Q7551384:	[]
# Q618123:	[]
# Q27096213:	[]
# Q82794:	[]
# Q2221906:	[]
# Q73278267:	[]
# Q29918292:	[]
# Q48204:	[]
# Q79913:	[]
# Q163740:	[]
# Q15911314:	[]
# Q106668099:	[]
# Q11483816:	[]
# Q132241:	[]
# Q5043:	[]
# Q47280:	[]
# Q19842652:	[]
# Q5287:	[]
# Q33612:	[]
# Q98791755:	[]
# Q20162172:	[]
# Q34770:	[]
# Q17376908:	[]
# Q33648:	[]
# Q33742:	[]
# Q5369:	[]
# Q2238071:	[]
# Q5372:	[]
# Q5375:	[]
# Q5378:	[]
# Q5386:	[]
# Q5367:	[]
# Q878123:	[]
# Q2312410:	[]
# Q5849:	[]
# Q5873:	[]
# Q608:	[]
# Q107289510:	[]
# Q1190058:	[]
# Q16358629:	[]
# Q223642:	[]
# Q853725:	[]
# Q602884:	[]
# Q483247:	[]
# Q38183514:	[]
# Q813912:	[]
# Q3505845:	[]
# Q2990606:	[]
# Q4042967:	[]
# Q2990595:	[]
# Q14863654:	[]
# Q14885910:	[]
# Q3775883:	[]
# Q30600878:	[]
# Q228395:	[]
# Q22271532:	[]
# Q5891:	[]
# Q5930:	[]
# Q5994:	[]
# Q3152898:	[]
# Q1798603:	[]
# Q1051772:	[]
# Q34379:	[]
# Q267228:	[]
# Q52954:	[]
# Q4951628:	[]
# Q55724742:	[]
# Q55724736:	[]
# Q50829016:	[]
# Q76239:	[]
# Q230262:	[]
# Q6010:	[]
# Q11401:	[]
# Q373342:	[]
# Q6942562:	[]
# Q15116915:	[]
# Q1668139:	[]
# Q855395:	[]
# Q29182544:	[]
# Q35140:	[]
# Q2267705:	[]
# Q6186:	[]
# Q6199:	[]
# Q6241:	[]
# Q6388:	[]
# Q3467704:	[]
# Q22270382:	[]
# Q2633862:	[]
# Q2515874:	[]
# Q29374366:	[]
# Q6607:	[]
# Q57306162:	[]
# Q55724840:	[]
# Q55724833:	[]
# Q30038759:	[]
# Q1808578:	[]
# Q19588495:	[]
# Q6663:	[]
# Q746549:	[]
# Q2095:	[]
# Q1194058:	[]
# Q1681365:	[]
# Q6851:	[]
# Q7026:	[]
# Q599958:	[]
# Q500394:	[]
# Q954321:	[]
# Q2714388:	[]
# Q112608:	[]
# Q19814:	[]
# Q131848:	[]
# Q7094:	[]
# Q11351:	[]
# Q7100:	[]
# Q7108:	[]
# Q7141:	[]
# Q7150:	[]
# Q7156:	[]
# Q7162:	[]
# Q7163:	[]
# Q3482410:	[]
# Q4686698:	[]
# Q1331926:	[]
# Q781413:	[]
# Q12888920:	[]
# Q12791748:	[]
# Q7168:	[]
# Q7173:	[]
# Q5728861:	[]
# Q4782809:	[]
# Q1130698:	[]
# Q7175:	[]
# Q7178:	[]
# Q7188:	[]
# Q1125239:	[]
# Q2659904:	[]
# Q895526:	[]
# Q327333:	[]
# Q155076:	[]
# Q7210356:	[]
# Q15708736:	[]
# Q174834:	[]
# Q25107:	[]
# Q780687:	[]
# Q321839:	[]
# Q2006324:	[]
# Q202722:	[]
# Q7193:	[]
# Q7202:	[]
# Q7205:	[]
# Q7206:	[]
# Q23404:	[]
# Q34749:	[]
# Q1999851:	[]
# Q7208:	[]
# Q2057971:	[]
# Q7189713:	[]
# Q621184:	[]
# Q639907:	[]
# Q193181:	[]
# Q160402:	[]
# Q87075524:	[]
# Q944806:	[]
# Q1132455:	[]
# Q5422048:	[]
# Q86923152:	[]
# Q18603648:	[]
# Q7215:	[]
# Q7218:	[]
# Q7252:	[]
# Q223569:	[]
# Q2386606:	[]
# Q7748:	[]
# Q1151067:	[]
# Q628523:	[]
# Q8458:	[]
# Q7269:	[]
# Q22676587:	[]
# Q1307214:	[]
# Q183039:	[]
# Q28108:	[]
# Q1639378:	[]
# Q2752458:	[]
# Q5962346:	[]
# Q6423319:	[]
# Q7278:	[]
# Q7281:	[]
# Q905726:	[]
# Q1307337:	[]
# Q98144857:	[]
# Q18812548:	[]
# Q180684:	[]
# Q839578:	[]
# Q609298:	[]
# Q7283:	[]
# Q2571535:	[]
# Q83267:	[]
# Q24962887:	[]
# Q6765918:	[]
# Q7291:	[]
# Q7358:	['artist', 'performing artist']
# Q10774753:	['artist', 'performing artist']
# Q3391743:	['artist']
# Q108289408:	[]
# Q108289030:	[]
# Q110281945:	[]
# Q702269:	[]
# Q17307272:	['artist', 'performing artist']
# Q7363:	[]
# Q24060765:	[]
# Q712378:	[]
# Q4936952:	[]
# Q28845870:	[]
# Q1310239:	[]
# Q15989253:	[]
# Q16686022:	[]
# Q27043948:	[]
# Q66394244:	[]
# Q53617407:	[]
# Q35758:	[]
# Q28728771:	[]
# Q25570959:	[]
# Q7366:	[]
# Q685884:	[]
# Q3689704:	[]
# Q2989679:	[]
# Q7397:	[]
# Q7411:	[]
# Q153050:	[]
# Q330129:	[]
# Q7553:	[]
# Q11398090:	[]
# Q7560:	[]
# Q7566:	[]
# Q25098571:	[]
# Q12758374:	[]
# Q7565:	[]
# Q84048850:	[]
# Q7590:	[]
# Q4284762:	[]
# Q3074541:	[]
# Q7687:	[]
# Q7718:	[]
# Q216613:	[]
# Q130949:	[]
# Q204686:	[]
# Q484937:	[]
# Q7735:	[]
# Q61065:	[]
# Q3493904:	[]
# Q3493900:	[]
# Q7737:	[]
# Q144713:	[]
# Q23526:	[]
# Q147356:	[]
# Q7809:	[]
# Q7845:	[]
# Q7856:	[]
# Q7867:	[]
# Q7922:	[]
# Q944537:	[]
# Q1587903:	[]
# Q8434:	[]
# Q133500:	[]
# Q14819853:	[]
# Q2200417:	[]
# Q7406919:	[]
# Q8028:	[]
# Q6949149:	[]
# Q2239243:	[]
# Q28020127:	[]
# Q30017383:	[]
# Q14897293:	[]
# Q64728693:	[]
# Q2593744:	[]
# Q95074:	[]
# Q97626363:	[]
# Q20828805:	[]
# Q193291:	[]
# Q11458821:	[]
# Q502931:	[]
# Q8076:	[]
# Q15654425:	[]
# Q11422:	[]
# Q17538258:	[]
# Q581105:	[]
# Q2858615:	[]
# Q2425052:	[]
# Q931447:	[]
# Q210729:	[]
# Q66310125:	[]
# Q3749263:	[]
# Q2249149:	[]
# Q241317:	[]
# Q55417699:	[]
# Q1836700:	[]
# Q8134:	[]
# Q8162:	[]
# Q8236:	[]
# Q205961:	[]
# Q8253:	[]
# Q8261:	[]
# Q8311:	['media professional']
# Q1240788:	[]
# Q2462658:	[]
# Q25713832:	[]
# Q978044:	[]
# Q1863288:	[]
# Q18029574:	[]
# Q8313:	['media professional']
# Q8317:	[]
# Q1001378:	[]
# Q11177771:	[]
# Q11016:	[]
# Q381243:	[]
# Q15088947:	[]
# Q174923:	[]
# Q182593:	[]
# Q46945201:	[]
# Q12047512:	[]
# Q11999558:	[]
# Q8325:	[]
# Q11409220:	[]
# Q131207:	[]
# Q79529:	[]
# Q43460564:	[]
# Q378078:	[]
# Q28732711:	[]
# Q2114846:	[]
# Q12013292:	[]
# Q173514:	[]
# Q16920758:	[]
# Q5158735:	[]
# Q1479406:	[]
# Q2251595:	[]
# Q8338:	[]
# Q180744:	[]
# Q173453:	[]
# Q659216:	[]
# Q8341:	[]
# Q8343:	[]
# Q185626:	[]
# Q3152896:	[]
# Q42896320:	[]
# Q181247:	[]
# Q217306:	[]
# Q55738872:	[]
# Q55738870:	[]
# Q55738869:	[]
# Q8350:	[]
# Q55738923:	[]
# Q55738916:	[]
# Q98329515:	[]
# Q8355:	[]
# Q57050725:	[]
# Q192096:	[]
# Q8362:	[]
# Q3305213:	[]
# Q110304307:	[]
# Q8392:	[]
# Q178059:	[]
# Q7256482:	[]
# Q18553616:	[]
# Q12135:	[]
# Q12136:	[]
# Q8418:	[]
# Q8421:	[]
# Q2876213:	[]
# Q8427:	[]
# Q476294:	[]
# Q928786:	[]
# Q1665984:	[]
# Q2465832:	[]
# Q1047113:	[]
# Q110403031:	[]
# Q23010558:	[]
# Q1143546:	[]
# Q42240:	[]
# Q8441:	[]
# Q8473:	[]
# Q8513:	[]
# Q494756:	[]
# Q8641:	[]
# Q52040:	[]
# Q615948:	[]
# Q8646:	[]
# Q8682:	[]
# Q8752:	[]
# Q4669240:	[]
# Q85380120:	[]
# Q9212:	[]
# Q9402:	[]
# Q178197:	[]
# Q1250916:	[]
# Q1414937:	[]
# Q5179297:	[]
# Q5446967:	[]
# Q9352089:	[]
# Q392651:	[]
# Q57735705:	[]
# Q9418:	[]
# Q9471:	[]
# Q9531:	[]
# Q9581:	[]
# Q184663:	[]
# Q9592:	[]
# Q34651:	[]
# Q1530022:	[]
# Q4204511:	[]
# Q9603:	[]
# Q432:	[]
# Q45996:	[]
# Q5410500:	[]
# Q9764:	[]
# Q964987:	[]
# Q18345375:	[]
# Q205049:	[]
# Q106508039:	[]
# Q3328676:	[]
# Q201022:	[]
# Q3209069:	[]
# Q11639:	[]
# Q9798:	[]
# Q55738874:	[]
# Q10135:	[]
# Q10251:	[]
# Q11432:	[]
# Q102205:	[]
# Q4437984:	[]
# Q1704572:	[]
# Q25416091:	[]
# Q66591990:	[]
# Q66591980:	[]
# Q10300:	[]
# Q10379:	[]
# Q10387:	[]
# Q10640:	[]
# Q10737:	[]
# Q844482:	[]
# Q124490:	[]
# Q4072473:	[]
# Q191797:	[]
# Q25395884:	[]
# Q60971579:	[]
# Q10931:	[]
# Q1510761:	[]
# Q26132748:	[]
# Q1673271:	[]
# Q23009439:	[]
# Q99632598:	[]
# Q22087155:	[]
# Q10962:	[]
# Q10980:	[]
# Q43767805:	[]
# Q11023:	[]
# Q3958441:	[]
# Q11030:	[]
# Q11034:	[]
# Q1408286:	[]
# Q11063:	['scientist']
# Q11068:	[]
# Q188193:	[]
# Q30336093:	[]
# Q6506039:	[]
# Q106865236:	[]
# Q11073:	[]
# Q11180:	[]
# Q11204:	[]
# Q1752346:	[]
# Q2324993:	[]
# Q2101636:	[]
# Q11211:	[]
# Q11214:	[]
# Q11345:	[]
# Q976981:	[]
# Q1140046:	[]
# Q2001982:	[]
# Q7512598:	[]
# Q6498784:	[]
# Q3435924:	[]
# Q1166625:	[]
# Q759676:	[]
# Q1438033:	[]
# Q23312670:	[]
# Q22445448:	[]
# Q24034552:	[]
# Q11218:	[]
# Q11281:	[]
# Q278368:	[]
# Q613354:	[]
# Q11372:	[]
# Q11399:	[]
# Q11403:	[]
# Q899215:	[]
# Q727781:	[]
# Q3328669:	[]
# Q5645984:	[]
# Q11405:	[]
# Q11416:	[]
# Q3590573:	[]
# Q8187769:	[]
# Q12737077:	[]
# Q1807498:	[]
# Q214339:	[]
# Q4897819:	[]
# Q100195948:	[]
# Q11417:	[]
# Q11419:	[]
# Q11420:	[]
# Q7128792:	[]
# Q337979:	[]
# Q2284014:	[]
# Q752021:	[]
# Q1280410:	[]
# Q831454:	[]
# Q19902211:	[]
# Q11424:	[]
# Q10301427:	[]
# Q478798:	[]
# Q11795009:	[]
# Q174984:	[]
# Q2150504:	[]
# Q3695082:	[]
# Q11425:	[]
# Q932586:	[]
# Q21198548:	[]
# Q739302:	[]
# Q590870:	[]
# Q11633:	[]
# Q10296912:	[]
# Q36649:	[]
# Q11442:	[]
# Q595658:	[]
# Q5936788:	[]
# Q1507442:	[]
# Q2120578:	[]
# Q19279121:	[]
# Q41321608:	[]
# Q233040:	[]
# Q11723891:	[]
# Q768186:	[]
# Q2184715:	[]
# Q18458812:	[]
# Q11451:	[]
# Q55640:	[]
# Q1801887:	[]
# Q159810:	[]
# Q11467:	[]
# Q228736:	[]
# Q12015335:	[]
# Q21213340:	[]
# Q11468:	[]
# Q11629:	[]
# Q11631:	['scientist', 'transportation occupation']
# Q373021:	['transportation occupation']
# Q345844:	[]
# Q11634:	[]
# Q17310537:	[]
# Q11642:	[]
# Q877729:	[]
# Q29028649:	[]
# Q2207288:	[]
# Q11661:	[]
# Q5268834:	[]
# Q11696:	[]
# Q11699:	[]
# Q42178:	[]
# Q3250324:	[]
# Q2269913:	[]
# Q1758037:	[]
# Q140686:	[]
# Q11739:	[]
# Q11756:	[]
# Q465299:	[]
# Q11042:	[]
# Q2515887:	[]
# Q2083958:	[]
# Q4184950:	[]
# Q11990:	[]
# Q12097:	['politician']
# Q12100:	[]
# Q12128:	[]
# Q12187:	[]
# Q12140:	[]
# Q8386:	[]
# Q409205:	[]
# Q28885102:	[]
# Q86746756:	[]
# Q50377176:	[]
# Q50379781:	[]
# Q50377224:	[]
# Q50377228:	[]
# Q1724915:	[]
# Q178859:	[]
# Q68541106:	[]
# Q11173:	[]
# Q578779:	[]
# Q20026787:	[]
# Q19478619:	[]
# Q5127848:	[]
# Q804539:	[]
# Q12271:	[]
# Q82604:	[]
# Q12479:	[]
# Q12483:	[]
# Q12539:	[]
# Q12567:	[]
# Q12631:	[]
# Q12681:	[]
# Q37260:	[]
# Q974688:	[]
# Q4425763:	[]
# Q8192:	[]
# Q12684:	[]
# Q12725:	[]
# Q11379:	[]
# Q107715:	[]
# Q4373292:	[]
# Q309314:	[]
# Q71550118:	[]
# Q181175:	[]
# Q1289248:	[]
# Q2204117:	[]
# Q188524:	[]
# Q21550639:	[]
# Q379825:	[]
# Q5358816:	[]
# Q2091629:	[]
# Q1325769:	[]
# Q3386703:	[]
# Q21855572:	[]
# Q28733284:	[]
# Q1747793:	[]
# Q28859120:	[]
# Q1370617:	[]
# Q1413749:	[]
# Q180953:	[]
# Q1397059:	[]
# Q3058239:	[]
# Q192276:	[]
# Q11348:	[]
# Q130901:	[]
# Q1756942:	[]
# Q629085:	[]
# Q54940067:	[]
# Q5165061:	[]
# Q1657198:	[]
# Q95744479:	[]
# Q22963169:	[]
# Q215111:	[]
# Q1522115:	[]
# Q12739:	[]
# Q12765:	[]
# Q13136:	[]
# Q1063801:	[]
# Q1754533:	[]
# Q3523102:	[]
# Q1348645:	[]
# Q1068473:	[]
# Q13887:	[]
# Q13955:	[]
# Q34049:	[]
# Q25268:	[]
# Q13968:	['civil servant']
# Q14211:	['politician', 'civil servant']
# Q14212:	['politician', 'civil servant']
# Q2285706:	['politician']
# Q83307:	['civil servant']
# Q108290289:	['civil servant']
# Q108289363:	[]
# Q108289024:	[]
# Q1544356:	[]
# Q14213:	['civil servant']
# Q7330070:	['civil servant']
# Q736559:	['civil servant']
# Q14284:	['jurist']
# Q40348:	['jurist']
# Q108289403:	[]
# Q14373:	[]
# Q36963:	[]
# Q861451:	[]
# Q192581:	[]
# Q6958747:	[]
# Q17232516:	[]
# Q47728:	[]
# Q14502:	[]
# Q14620:	[]
# Q15180:	[]
# Q15416:	[]
# Q11578774:	[]
# Q7725310:	[]
# Q17489659:	[]
# Q15862:	[]
# Q16320:	[]
# Q16406:	[]
# Q213441:	[]
# Q628858:	[]
# Q13226383:	[]
# Q811430:	[]
# Q35145743:	[]
# Q27096235:	[]
# Q49416455:	[]
# Q655686:	[]
# Q41176:	[]
# Q811979:	[]
# Q11908691:	[]
# Q15710813:	[]
# Q4830453:	[]
# Q3563237:	[]
# Q16533:	['jurist', 'civil servant']
# Q6302990:	['civil servant']
# Q108290452:	[]
# Q108289427:	[]
# Q108289033:	[]
# Q108286936:	[]
# Q6503343:	['civil servant']
# Q16750:	[]
# Q17221:	[]
# Q11997597:	[]
# Q17514:	[]
# Q17516:	[]
# Q15852218:	[]
# Q6160:	[]
# Q65659335:	[]
# Q857984:	[]
# Q481609:	[]
# Q47496130:	[]
# Q1640824:	[]
# Q55412936:	[]
# Q17955:	[]
# Q18127:	[]
# Q1417728:	[]
# Q837816:	[]
# Q82799:	[]
# Q8171:	[]
# Q2944660:	[]
# Q20817253:	[]
# Q29651519:	[]
# Q111352:	[]
# Q5371079:	[]
# Q12767945:	[]
# Q1886349:	[]
# Q167270:	[]
# Q80071:	[]
# Q431289:	[]
# Q18231:	[]
# Q18244:	['politician']
# Q18281:	[]
# Q1817291:	[]
# Q7708485:	[]
# Q770899:	[]
# Q18334:	[]
# Q658544:	[]
# Q18336:	[]
# Q770723:	[]
# Q1066186:	[]
# Q11790198:	[]
# Q18362:	[]
# Q18805:	['scientist']
# Q18811:	['politician', 'civil servant']
# Q175240:	['civil servant']
# Q19100:	['military personnel']
# Q1156796:	['military personnel']
# Q189290:	['military personnel']
# Q61022630:	[]
# Q19546:	['clergyperson', 'politician']
# Q102039658:	['clergyperson']
# Q611644:	['clergyperson']
# Q29182:	['clergyperson']
# Q1423891:	['clergyperson']
# Q105200223:	[]
# Q2259532:	[]
# Q4504549:	[]
# Q831474:	['clergyperson']
# Q42603:	['clergyperson']
# Q1638918:	['clergyperson']
# Q105200214:	[]
# Q104049627:	['clergyperson']
# Q104050289:	['clergyperson']
# Q105200154:	[]
# Q15995642:	[]
# Q105393558:	['clergyperson']
# Q105070520:	['clergyperson']
# Q189854:	['clergyperson']
# Q49476:	['clergyperson']
# Q48629921:	['clergyperson']
# Q1144278:	['clergyperson']
# Q106968578:	[]
# Q105096667:	['clergyperson']
# Q171692:	['clergyperson']
# Q19641:	['jurist']
# Q673566:	['jurist']
# Q105275968:	[]
# Q17575128:	[]
# Q184402:	[]
# Q71986641:	[]
# Q47740:	[]
# Q17573152:	[]
# Q19643:	['politician']
# Q16511993:	['politician']
# Q19652:	[]
# Q272458:	[]
# Q20599:	[]
# Q20657:	[]
# Q20899:	[]
# Q1076968:	[]
# Q1209283:	[]
# Q269415:	[]
# Q867147:	[]
# Q21164:	[]
# Q21201:	[]
# Q22667:	[]
# Q350783:	[]
# Q376799:	[]
# Q1826691:	[]
# Q1228250:	[]
# Q211548:	[]
# Q815741:	[]
# Q207961:	[]
# Q83620:	[]
# Q2874718:	[]
# Q22687:	[]
# Q1416431:	[]
# Q650241:	[]
# Q730038:	[]
# Q6881511:	[]
# Q362482:	[]
# Q679206:	[]
# Q5260792:	[]
# Q22719:	[]
# Q22722:	[]
# Q22819:	[]
# Q91143339:	[]
# Q22932:	['politician']
# Q28989:	['politician']
# Q3519259:	['politician']
# Q5737899:	[]
# Q355567:	[]
# Q216353:	[]
# Q187931:	[]
# Q618779:	[]
# Q7302601:	[]
# Q230788:	[]
# Q4189293:	[]
# Q4120621:	[]
# Q187588:	[]
# Q841628:	[]
# Q2725376:	[]
# Q16744001:	['politician']
# Q2478141:	['politician']
# Q134737:	[]
# Q22947:	[]
# Q23498:	[]
# Q23640:	[]
# Q17781690:	[]
# Q27062218:	[]
# Q20088819:	[]
# Q23739:	[]
# Q1366112:	[]
# Q21010853:	[]
# Q5398426:	[]
# Q191489:	[]
# Q7724161:	[]
# Q15709880:	[]
# Q23839:	[]
# Q635280:	[]
# Q181156:	[]
# Q5253831:	[]
# Q21075690:	[]
# Q77654221:	[]
# Q66747123:	[]
# Q1391494:	[]
# Q17951:	[]
# Q315:	[]
# Q33005:	[]
# Q207101:	[]
# Q1474516:	[]
# Q20826827:	[]
# Q3329375:	[]
# Q1725664:	[]
# Q1235196:	[]
# Q24862:	[]
# Q25261:	[]
# Q757520:	[]
# Q188847:	[]
# Q25363:	[]
# Q25670:	[]
# Q15087423:	[]
# Q1334738:	[]
# Q317623:	[]
# Q106418668:	[]
# Q12453:	[]
# Q791801:	[]
# Q37112258:	[]
# Q1781028:	[]
# Q25853:	[]
# Q25866:	[]
# Q25931691:	[]
# Q10843872:	[]
# Q104637425:	[]
# Q1474521:	[]
# Q1168263:	[]
# Q207449:	[]
# Q25975:	[]
# Q26102:	['activist']
# Q47217:	[]
# Q3109572:	[]
# Q754479:	[]
# Q76611:	[]
# Q2915955:	[]
# Q5389993:	[]
# Q17737:	[]
# Q117850:	[]
# Q49773:	[]
# Q3533467:	[]
# Q203764:	[]
# Q273120:	[]
# Q26250:	[]
# Q26303:	[]
# Q917206:	[]
# Q21467672:	[]
# Q110373504:	[]
# Q3312129:	[]
# Q105674:	[]
# Q2535935:	[]
# Q925958:	[]
# Q219067:	[]
# Q29051769:	[]
# Q14536140:	[]
# Q56037271:	[]
# Q106170525:	[]
# Q5610504:	[]
# Q3757197:	[]
# Q20679883:	[]
# Q13208902:	[]
# Q60429516:	[]
# Q26383:	[]
# Q26409:	[]
# Q96239483:	[]
# Q56019:	[]
# Q27169:	['politician']
# Q486839:	['politician']
# Q4175034:	['politician']
# Q9200127:	[]
# Q27306:	[]
# Q27349:	['health professional']
# Q3332438:	['health professional']
# Q39631:	['health professional']
# Q16061291:	['health professional']
# Q108289390:	['health professional']
# Q27443:	[]
# Q27518:	[]
# Q282049:	[]
# Q20127274:	[]
# Q59157079:	[]
# Q27654:	[]
# Q27686:	[]
# Q1431026:	[]
# Q55638:	[]
# Q27887:	[]
# Q27908:	[]
# Q27911:	[]
# Q17172850:	[]
# Q7390:	[]
# Q97234227:	[]
# Q6980787:	[]
# Q95605854:	[]
# Q27914:	['musician']
# Q98116969:	[]
# Q177220:	['musician']
# Q2643890:	['musician']
# Q27939:	[]
# Q27968:	[]
# Q11790583:	[]
# Q40634:	[]
# Q27997:	[]
# Q28065:	[]
# Q495304:	[]
# Q28161:	[]
# Q28389:	['writer']
# Q28598:	[]
# Q28617:	[]
# Q28654:	[]
# Q179294:	[]
# Q16516071:	[]
# Q24841818:	[]
# Q28813:	[]
# Q19:	[]
# Q3796713:	[]
# Q31172650:	[]
# Q2393196:	[]
# Q170028:	[]
# Q600571:	[]
# Q1920219:	[]
# Q78908682:	[]
# Q15734480:	[]
# Q1184244:	[]
# Q1772449:	[]
# Q28823:	[]
# Q214609:	[]
# Q28555911:	[]
# Q6005984:	[]
# Q28921572:	[]
# Q28837:	['health professional']
# Q28865:	[]
# Q28914:	[]
# Q43115:	[]
# Q11681141:	[]
# Q28997:	[]
# Q1806324:	[]
# Q144:	[]
# Q39201:	[]
# Q228534:	[]
# Q29051:	[]
# Q29171:	[]
# Q4793045:	[]
# Q29282:	['clergyperson']
# Q105079980:	['clergyperson']
# Q93479414:	['clergyperson']
# Q102040941:	['clergyperson']
# Q105200498:	[]
# Q29358:	[]
# Q500050:	[]
# Q29536:	[]
# Q29552:	[]
# Q29583:	[]
# Q30022:	[]
# Q11707:	[]
# Q62602544:	[]
# Q27038993:	[]
# Q88985865:	[]
# Q41958:	[]
# Q30185:	['politician']
# Q10547393:	['politician']
# Q30461:	['politician']
# Q30849:	[]
# Q35127:	[]
# Q1714118:	[]
# Q15938550:	[]
# Q81941037:	[]
# Q19967801:	[]
# Q1668024:	[]
# Q1640628:	[]
# Q146923:	[]
# Q146768:	[]
# Q676202:	[]
# Q21044027:	[]
# Q107307154:	[]
# Q17334923:	[]
# Q58416391:	[]
# Q108637623:	[]
# Q1002697:	[]
# Q2217301:	[]
# Q28314507:	[]
# Q202833:	[]
# Q30903:	[]
# Q50810224:	[]
# Q31184:	[]
# Q31207:	[]
# Q2421951:	[]
# Q31561:	[]
# Q424111:	[]
# Q31687:	[]
# Q31728:	[]
# Q3754526:	[]
# Q11771944:	[]
# Q35798:	[]
# Q50412353:	[]
# Q428148:	[]
# Q31732:	[]
# Q717040:	[]
# Q207697:	[]
# Q2293362:	[]
# Q860861:	[]
# Q3370053:	[]
# Q4989906:	[]
# Q210272:	[]
# Q2434238:	[]
# Q23893363:	[]
# Q28870066:	[]
# Q31874:	[]
# Q213934:	[]
# Q2357239:	[]
# Q49389:	[]
# Q9323634:	[]
# Q1959446:	[]
# Q15851294:	[]
# Q1931791:	[]
# Q2141830:	[]
# Q155930:	[]
# Q31895:	[]
# Q31920:	[]
# Q32112:	[]
# Q32483:	[]
# Q32485:	[]
# Q1163125:	[]
# Q29428403:	[]
# Q32554:	['computer scientist']
# Q33203:	[]
# Q23540:	[]
# Q33226:	[]
# Q179661:	[]
# Q796194:	[]
# Q46857:	[]
# Q1799072:	[]
# Q26256310:	[]
# Q33231:	['artist']
# Q108289430:	[]
# Q33487:	[]
# Q11976924:	[]
# Q13631330:	[]
# Q60539481:	[]
# Q9415:	[]
# Q282250:	[]
# Q3962655:	[]
# Q2684591:	[]
# Q309406:	[]
# Q46545345:	[]
# Q30893921:	[]
# Q41112:	[]
# Q170082:	[]
# Q3065932:	[]
# Q1441305:	[]
# Q2903417:	[]
# Q30085742:	[]
# Q31836626:	[]
# Q169872:	[]
# Q28807560:	[]
# Q2729863:	[]
# Q79871:	[]
# Q169207:	[]
# Q160232:	[]
# Q742736:	[]
# Q12578182:	[]
# Q5937752:	[]
# Q29485:	[]
# Q1747121:	[]
# Q1475848:	[]
# Q2142347:	[]
# Q186290:	[]
# Q5850078:	[]
# Q156318:	[]
# Q64705767:	[]
# Q1789452:	[]
# Q194112:	[]
# Q211364:	[]
# Q17736:	[]
# Q33506:	[]
# Q570116:	[]
# Q960648:	[]
# Q33521:	[]
# Q33526:	[]
# Q33999:	['performing artist']
# Q34168:	[]
# Q34187:	[]
# Q34362:	[]
# Q483677:	[]
# Q28954762:	[]
# Q8027727:	[]
# Q7254446:	[]
# Q1412596:	[]
# Q13579947:	[]
# Q105952144:	[]
# Q34508:	[]
# Q34740:	[]
# Q35245:	[]
# Q35377:	[]
# Q2743643:	[]
# Q1141096:	[]
# Q33253:	[]
# Q37228:	[]
# Q771124:	[]
# Q33838:	[]
# Q35395:	[]
# Q110761784:	[]
# Q35535:	[]
# Q732717:	[]
# Q35760:	[]
# Q3752011:	[]
# Q105685558:	[]
# Q35986:	[]
# Q35991:	[]
# Q34005:	[]
# Q34113:	[]
# Q728651:	[]
# Q206577:	[]
# Q36192:	[]
# Q36380:	[]
# Q36389:	[]
# Q36442:	[]
# Q15831440:	[]
# Q36524:	[]
# Q1469824:	[]
# Q6499736:	[]
# Q1172284:	[]
# Q2668072:	[]
# Q36633:	[]
# Q2990601:	[]
# Q2990599:	[]
# Q73822:	[]
# Q36774:	[]
# Q5358404:	[]
# Q1260632:	[]
# Q1424639:	[]
# Q36834:	['musician']
# Q482980:	[]
# Q36908:	[]
# Q820236:	[]
# Q968907:	[]
# Q3505012:	[]
# Q22857:	[]
# Q36956:	[]
# Q18553247:	[]
# Q727028:	[]
# Q18123741:	[]
# Q42417296:	[]
# Q25383952:	[]
# Q55286823:	[]
# Q4293079:	[]
# Q18928530:	[]
# Q19597369:	[]
# Q3041498:	[]
# Q18554821:	[]
# Q18553219:	[]
# Q3339235:	[]
# Q18557436:	[]
# Q93176349:	[]
# Q945238:	[]
# Q7705854:	[]
# Q6742925:	[]
# Q7314317:	[]
# Q29033580:	[]
# Q54932071:	[]
# Q386014:	[]
# Q16259132:	[]
# Q11491601:	[]
# Q2656762:	[]
# Q2072214:	[]
# Q18555048:	[]
# Q2661443:	[]
# Q18558209:	[]
# Q3286546:	[]
# Q929451:	[]
# Q1345671:	[]
# Q1936838:	[]
# Q37038:	[]
# Q29584347:	[]
# Q17493662:	[]
# Q37073:	[]
# Q37110:	['politician']
# Q37137:	[]
# Q6983813:	[]
# Q37158:	[]
# Q37226:	['educator']
# Q37266:	[]
# Q37547:	[]
# Q37681:	[]
# Q629103:	[]
# Q28969293:	[]
# Q3405827:	[]
# Q188460:	[]
# Q11879003:	[]
# Q15075845:	[]
# Q28468832:	[]
# Q84230:	[]
# Q1435575:	[]
# Q14904806:	[]
# Q12552022:	[]
# Q323426:	[]
# Q14905243:	[]
# Q66986433:	[]
# Q14873025:	[]
# Q14860403:	[]
# Q29548:	[]
# Q14349455:	[]
# Q70551253:	[]
# Q5058355:	[]
# Q47507412:	[]
# Q874142:	[]
# Q1192049:	[]
# Q161:	[]
# Q8054:	[]
# Q422649:	[]
# Q81163:	[]
# Q169336:	[]
# Q206229:	[]
# Q901227:	[]
# Q542929:	[]
# Q192355:	[]
# Q178593:	[]
# Q11369:	[]
# Q2393187:	[]
# Q424689:	[]
# Q174211:	[]
# Q2901852:	[]
# Q3084232:	[]
# Q172847:	[]
# Q355679:	[]
# Q188777:	[]
# Q9392635:	[]
# Q66560214:	[]
# Q37726:	[]
# Q37732:	[]
# Q38022:	[]
# Q38108:	[]
# Q779272:	[]
# Q31883501:	[]
# Q14300548:	[]
# Q38112:	[]
# Q18218474:	[]
# Q29584207:	[]
# Q38142:	[]
# Q38490:	[]
# Q1193939:	[]
# Q4990963:	[]
# Q918385:	[]
# Q38523:	[]
# Q1270589:	[]
# Q38677:	[]
# Q227675:	[]
# Q995745:	[]
# Q1094654:	[]
# Q18054608:	[]
# Q4023882:	[]
# Q80962:	[]
# Q56299222:	[]
# Q17277530:	[]
# Q38695:	[]
# Q38774:	[]
# Q38826:	[]
# Q38883:	[]
# Q1294787:	[]
# Q2588761:	[]
# Q1391344:	[]
# Q33394058:	[]
# Q12713481:	[]
# Q1191714:	[]
# Q703534:	[]
# Q852998:	[]
# Q656720:	[]
# Q12144897:	[]
# Q38967:	[]
# Q39018:	['politician']
# Q39235:	[]
# Q12210238:	[]
# Q39286:	[]
# Q3520855:	[]
# Q12744095:	[]
# Q39372:	['transportation occupation']
# Q2095549:	['transportation occupation']
# Q254651:	[]
# Q5184855:	[]
# Q23640580:	[]
# Q11998775:	[]
# Q22813352:	[]
# Q39453:	[]
# Q39689:	[]
# Q178934:	[]
# Q39809:	[]
# Q39818:	[]
# Q40125:	[]
# Q11351992:	[]
# Q40221:	[]
# Q40244:	[]
# Q40403:	[]
# Q40561:	[]
# Q40821:	[]
# Q40831:	[]
# Q40998:	[]
# Q41171:	[]
# Q41217:	[]
# Q41253:	[]
# Q294422:	[]
# Q17350442:	[]
# Q1496967:	[]
# Q41259:	[]
# Q41298:	[]
# Q39725049:	[]
# Q1261026:	[]
# Q82036085:	[]
# Q41300:	[]
# Q41323:	[]
# Q1546270:	[]
# Q41374:	[]
# Q41425:	[]
# Q1020618:	[]
# Q41466:	[]
# Q41569:	['military personnel']
# Q1261521:	[]
# Q1970438:	[]
# Q41583:	['sportsperson (non-athlete)']
# Q1781513:	[]
# Q41630:	[]
# Q41674:	['scientist', 'engineer']
# Q1709010:	['scientist', 'engineer']
# Q1572123:	['engineer']
# Q5157565:	['scientist']
# Q41675:	[]
# Q41685:	['military personnel']
# Q41767:	[]
# Q56604289:	[]
# Q42002:	[]
# Q42042:	[]
# Q42250:	[]
# Q42388:	[]
# Q6235:	[]
# Q12909644:	[]
# Q42418:	[]
# Q42486:	[]
# Q15041854:	[]
# Q650711:	[]
# Q1931388:	[]
# Q42515:	[]
# Q42569:	[]
# Q42759:	[]
# Q42767:	[]
# Q42814:	[]
# Q42841:	[]
# Q42857:	[]
# Q42909:	['journalist']
# Q42944:	[]
# Q42973:	['designer']
# Q42998:	[]
# Q11072804:	[]
# Q215380:	[]
# Q2088357:	[]
# Q32178211:	[]
# Q105815710:	[]
# Q109802395:	[]
# Q43006:	[]
# Q678649:	[]
# Q213156:	[]
# Q107196743:	[]
# Q4684642:	[]
# Q1065579:	[]
# Q11460:	[]
# Q362200:	[]
# Q43015:	[]
# Q18564125:	[]
# Q43035:	[]
# Q43173:	[]
# Q1640717:	[]
# Q41487:	[]
# Q1412224:	[]
# Q43183:	[]
# Q15809678:	[]
# Q837171:	[]
# Q25351891:	[]
# Q806750:	[]
# Q29584336:	[]
# Q100263230:	[]
# Q43250:	[]
# Q43292:	['politician']
# Q43343:	[]
# Q43412:	['clergyperson']
# Q20643955:	[]
# Q21070568:	[]
# Q12405827:	[]
# Q18563354:	[]
# Q13002315:	[]
# Q3658341:	[]
# Q43450:	[]
# Q43483:	[]
# Q867393:	[]
# Q124714:	[]
# Q35145263:	[]
# Q27096220:	[]
# Q15324:	[]
# Q20719696:	[]
# Q11924308:	[]
# Q1049799:	[]
# Q43504:	[]
# Q43518:	[]
# Q3349060:	[]
# Q43616:	[]
# Q48422:	[]
# Q170494:	[]
# Q2937981:	[]
# Q55082364:	[]
# Q10855061:	[]
# Q44356:	['politician']
# Q44455:	[]
# Q177571:	[]
# Q3919817:	[]
# Q44497:	[]
# Q44554:	[]
# Q4202277:	[]
# Q44687:	[]
# Q44784:	[]
# Q5151421:	[]
# Q17172848:	[]
# Q841971:	[]
# Q11615913:	[]
# Q44914:	[]
# Q13698:	[]
# Q45199:	['transportation occupation']
# Q7497908:	[]
# Q99547053:	['transportation occupation']
# Q45393:	[]
# Q1933595:	[]
# Q53706:	[]
# Q1520311:	[]
# Q2727213:	[]
# Q45529:	[]
# Q239872:	[]
# Q6549417:	[]
# Q45621:	[]
# Q11438:	[]
# Q45684:	[]
# Q45722:	[]
# Q45981:	[]
# Q46158:	[]
# Q2198855:	[]
# Q46185:	[]
# Q810447:	[]
# Q46241:	[]
# Q46255:	[]
# Q46337:	[]
# Q62662439:	[]
# Q46721:	[]
# Q46872:	[]
# Q15328:	[]
# Q1751850:	[]
# Q3099911:	[]
# Q2920313:	[]
# Q311666:	[]
# Q46952:	[]
# Q12754227:	[]
# Q4430243:	[]
# Q1788992:	[]
# Q46961:	[]
# Q2159907:	[]
# Q99485144:	[]
# Q46970:	[]
# Q1875615:	[]
# Q740752:	[]
# Q18019760:	[]
# Q765633:	[]
# Q107290157:	[]
# Q47140:	[]
# Q47307:	[]
# Q47315:	[]
# Q47369:	[]
# Q47398:	[]
# Q47506:	[]
# Q1077784:	[]
# Q312466:	[]
# Q40056:	[]
# Q4303335:	[]
# Q17638537:	[]
# Q4117406:	[]
# Q47594:	[]
# Q47805:	[]
# Q47913:	[]
# Q939616:	[]
# Q47928:	[]
# Q2416217:	[]
# Q327245:	[]
# Q742421:	[]
# Q13473501:	[]
# Q48277:	[]
# Q844569:	[]
# Q1860557:	[]
# Q48282:	[]
# Q11448873:	[]
# Q1339255:	[]
# Q48519:	[]
# Q48803:	[]
# Q173113:	[]
# Q48942:	[]
# Q49084:	[]
# Q38072107:	[]
# Q3328821:	[]
# Q49297:	[]
# Q15571255:	[]
# Q36747:	[]
# Q103817:	[]
# Q2472587:	[]
# Q41710:	[]
# Q2384959:	[]
# Q846570:	[]
# Q96158230:	[]
# Q49390:	[]
# Q752783:	[]
# Q5916:	[]
# Q206021:	[]
# Q29584737:	[]
# Q1757562:	[]
# Q29584220:	[]
# Q2133344:	[]
# Q13425175:	[]
# Q49624:	[]
# Q49640:	['transportation occupation']
# Q49683:	[]
# Q49757:	['writer']
# Q49780:	[]
# Q49958:	[]
# Q814232:	[]
# Q1438073:	[]
# Q64418432:	[]
# Q7257997:	[]
# Q4929239:	[]
# Q208165:	[]
# Q108634029:	[]
# Q58327829:	[]
# Q50009:	[]
# Q50637:	[]
# Q1757598:	[]
# Q352842:	[]
# Q4350200:	[]
# Q50641:	[]
# Q50675:	[]
# Q109023778:	[]
# Q50776:	[]
# Q51619:	[]
# Q106039:	[]
# Q51626:	[]
# Q12057431:	[]
# Q47472256:	[]
# Q51677:	['clergyperson']
# Q3114821:	['clergyperson']
# Q728973:	['clergyperson']
# Q6386590:	[]
# Q7325:	[]
# Q62928:	[]
# Q63361041:	[]
# Q51724:	[]
# Q14623646:	[]
# Q24577840:	[]
# Q14514600:	[]
# Q23010327:	[]
# Q108764372:	[]
# Q7970798:	[]
# Q733786:	[]
# Q102250838:	[]
# Q189829:	[]
# Q51785:	[]
# Q78817465:	[]
# Q17305127:	[]
# Q32859534:	[]
# Q14136353:	[]
# Q52106:	[]
# Q52107:	[]
# Q52109:	[]
# Q11862829:	[]
# Q52139:	[]
# Q52618:	[]
# Q52862:	[]
# Q52875:	[]
# Q53467:	[]
# Q5813294:	[]
# Q1124860:	[]
# Q53946:	[]
# Q54128:	[]
# Q464705:	[]
# Q108290509:	[]
# Q108289646:	[]
# Q108289040:	[]
# Q108285748:	[]
# Q54852:	[]
# Q55187:	[]
# Q27943370:	[]
# Q108289644:	[]
# Q56010:	[]
# Q56026:	[]
# Q56923:	['military personnel']
# Q83460:	['military personnel']
# Q57706:	[]
# Q58333:	['civil servant']
# Q2101758:	['civil servant']
# Q19476593:	[]
# Q384593:	['civil servant']
# Q58451:	['clergyperson']
# Q102387005:	['clergyperson']
# Q102385896:	['clergyperson']
# Q15283040:	['clergyperson']
# Q18246606:	['clergyperson']
# Q105275800:	[]
# Q7229148:	[]
# Q58848:	[]
# Q58854:	[]
# Q58967:	[]
# Q58968:	['humanities scholar']
# Q4964182:	['humanities scholar']
# Q59057:	['politician']
# Q719039:	['politician']
# Q5784340:	[]
# Q1196129:	[]
# Q59068:	[]
# Q16872093:	[]
# Q156864:	[]
# Q1413113:	[]
# Q1377029:	[]
# Q1595873:	[]
# Q59115:	[]
# Q59157:	[]
# Q3475773:	[]
# Q861399:	[]
# Q59597:	[]
# Q59774:	[]
# Q189753:	[]
# Q9163:	[]
# Q620805:	[]
# Q59831:	[]
# Q59950:	[]
# Q12831143:	[]
# Q60242:	[]
# Q18358830:	[]
# Q60523:	['clergyperson']
# Q60667:	[]
# Q60719:	['clergyperson']
# Q60797:	[]
# Q18342738:	[]
# Q60924:	[]
# Q60995:	[]
# Q61061:	['businessperson']
# Q108392111:	['businessperson']
# Q21281706:	['businessperson']
# Q5428874:	['businessperson']
# Q4359236:	['businessperson']
# Q11488158:	[]
# Q828803:	[]
# Q61341:	['health professional']
# Q7135767:	[]
# Q55071047:	['health professional']
# Q61372:	['politician']
# Q61465:	[]
# Q29343801:	[]
# Q61509:	[]
# Q61551:	[]
# Q1932461:	[]
# Q61883:	[]
# Q61982:	['politician']
# Q12826225:	['politician']
# Q1975935:	[]
# Q62689:	[]
# Q63100:	[]
# Q63327:	[]
# Q63765:	[]
# Q63473:	[]
# Q64909:	[]
# Q65997:	['politician']
# Q69596:	[]
# Q1770695:	[]
# Q1323698:	[]
# Q98528267:	[]
# Q525073:	[]
# Q70125:	[]
# Q749316:	[]
# Q13485782:	[]
# Q75178:	['clergyperson']
# Q1044528:	['clergyperson']
# Q193364:	['clergyperson']
# Q250867:	['clergyperson']
# Q75776:	[]
# Q76127:	[]
# Q77590:	[]
# Q77604:	[]
# Q177719:	[]
# Q79288:	[]
# Q79911:	[]
# Q80006:	[]
# Q80015:	[]
# Q80019:	[]
# Q80040:	[]
# Q80205:	[]
# Q265619:	[]
# Q12764401:	[]
# Q192658:	[]
# Q80284:	[]
# Q80687:	[]
# Q80831:	[]
# Q11653:	[]
# Q1815901:	[]
# Q132629:	[]
# Q80866:	['humanities scholar']
# Q80895:	[]
# Q6073630:	[]
# Q198:	[]
# Q350604:	[]
# Q71266556:	[]
# Q752673:	[]
# Q80919:	[]
# Q80993:	[]
# Q682496:	[]
# Q81058:	[]
# Q188504:	[]
# Q25312655:	[]
# Q81197:	[]
# Q81710:	['agricultural worker']
# Q12059906:	['agricultural worker']
# Q131512:	['agricultural worker']
# Q108290536:	[]
# Q108289653:	[]
# Q108289043:	[]
# Q108288352:	[]
# Q838811:	['agricultural worker']
# Q81741:	[]
# Q81982:	[]
# Q82650:	[]
# Q580939:	[]
# Q82723:	['performing artist']
# Q138858:	['performing artist']
# Q82753:	[]
# Q37787110:	[]
# Q30059018:	[]
# Q17176533:	[]
# Q66310127:	[]
# Q82811:	[]
# Q83042:	[]
# Q83172:	[]
# Q83204:	[]
# Q865588:	[]
# Q22950320:	[]
# Q83207:	[]
# Q15884100:	[]
# Q15220419:	[]
# Q41595400:	[]
# Q1054898:	[]
# Q83353:	[]
# Q83357:	[]
# Q11802861:	[]
# Q2050700:	[]
# Q17232201:	[]
# Q83372:	[]
# Q83405:	[]
# Q1497375:	[]
# Q18247357:	[]
# Q66661745:	[]
# Q61961344:	[]
# Q98119401:	[]
# Q99018632:	[]
# Q83462:	[]
# Q83944:	[]
# Q1063:	[]
# Q5418608:	[]
# Q3455898:	[]
# Q408891:	[]
# Q105210:	[]
# Q84066:	[]
# Q85708:	[]
# Q87167:	[]
# Q3331189:	[]
# Q93184:	[]
# Q93204:	[]
# Q24960157:	[]
# Q4164344:	[]
# Q94084:	['educator', 'businessperson']
# Q121594:	['educator', 'businessperson']
# Q1622272:	['educator', 'businessperson']
# Q19324694:	['educator']
# Q28031130:	[]
# Q101333:	[]
# Q101539:	['transportation occupation']
# Q95613235:	[]
# Q57610536:	[]
# Q101929:	[]
# Q101935:	[]
# Q101849:	[]
# Q102083:	[]
# Q102356:	[]
# Q9392615:	[]
# Q4005772:	[]
# Q66737643:	[]
# Q102904:	[]
# Q102932:	[]
# Q103076:	[]
# Q3691017:	[]
# Q103163:	['clergyperson']
# Q1776501:	['clergyperson']
# Q103350:	[]
# Q103824:	[]
# Q104319:	[]
# Q215168:	[]
# Q13414953:	[]
# Q855941:	[]
# Q104680:	['military personnel']
# Q1053745:	['military personnel']
# Q105186:	['health professional']
# Q105196:	[]
# Q600236:	[]
# Q15636229:	[]
# Q105269:	['athlete', 'sportsperson (non-athlete)']
# Q10873124:	['athlete', 'sportsperson (non-athlete)']
# Q73145133:	['sportsperson (non-athlete)']
# Q84380764:	[]
# Q18536342:	[]
# Q4197743:	[]
# Q11538946:	[]
# Q105527:	[]
# Q105611:	[]
# Q4201895:	[]
# Q105650:	[]
# Q106500:	[]
# Q106800:	[]
# Q107013:	[]
# Q6498826:	[]
# Q1851760:	[]
# Q107198:	[]
# Q107425:	[]
# Q107427:	[]
# Q670732:	[]
# Q107478:	[]
# Q50636:	[]
# Q858517:	[]
# Q107711:	[]
# Q17126809:	[]
# Q107885:	[]
# Q105606485:	[]
# Q108458:	[]
# Q955260:	[]
# Q6864036:	[]
# Q64831118:	[]
# Q23847174:	[]
# Q109960:	[]
# Q20778343:	[]
# Q110223:	[]
# Q165580:	[]
# Q110910:	[]
# Q111837:	[]
# Q112040:	[]
# Q1193763:	[]
# Q4610556:	[]
# Q112983:	[]
# Q4184:	[]
# Q36279:	[]
# Q15706467:	[]
# Q20540385:	[]
# Q17108519:	[]
# Q113109:	[]
# Q242468:	[]
# Q66035178:	[]
# Q108286044:	[]
# Q108286072:	[]
# Q108286084:	[]
# Q108285940:	[]
# Q113360:	[]
# Q1221110:	[]
# Q114466:	[]
# Q115266:	[]
# Q116494:	[]
# Q118865:	['musician']
# Q25616474:	['musician']
# Q1278335:	['musician']
# Q97572814:	['musician']
# Q119190:	[]
# Q119740:	[]
# Q70440108:	[]
# Q3411951:	[]
# Q64821189:	[]
# Q20862341:	[]
# Q5284418:	[]
# Q120569:	[]
# Q120931:	[]
# Q121176:	[]
# Q121254:	[]
# Q121998:	['civil servant']
# Q1251687:	['civil servant']
# Q193391:	['civil servant']
# Q1162163:	[]
# Q20920693:	[]
# Q15217354:	[]
# Q123006:	[]
# Q108487806:	[]
# Q34178:	[]
# Q15220629:	[]
# Q9268:	[]
# Q123028:	[]
# Q123030:	['transportation occupation']
# Q123305:	[]
# Q123432:	[]
# Q79751:	[]
# Q20076236:	[]
# Q4932206:	[]
# Q123585:	[]
# Q123637:	[]
# Q123695:	['civil servant']
# Q123795:	['scientist']
# Q124100:	[]
# Q124734:	[]
# Q13418847:	[]
# Q110227435:	[]
# Q124862:	[]
# Q2888028:	[]
# Q9263172:	[]
# Q95993050:	[]
# Q391009:	[]
# Q5135744:	[]
# Q225446:	[]
# Q2061186:	[]
# Q2742167:	[]
# Q51041800:	[]
# Q5982983:	[]
# Q177634:	[]
# Q124946:	[]
# Q125161:	[]
# Q649107:	[]
# Q222405:	[]
# Q728:	[]
# Q18643213:	[]
# Q125191:	[]
# Q125482:	[]
# Q125928:	[]
# Q16332653:	[]
# Q1322005:	[]
# Q58928516:	[]
# Q126095:	[]
# Q126214:	[]
# Q126236:	['military personnel', 'scientist']
# Q11900058:	['scientist']
# Q2873500:	['scientist']
# Q10498147:	['scientist']
# Q30093123:	[]
# Q1914017:	[]
# Q4991371:	['military personnel']
# Q126399:	[]
# Q126552:	[]
# Q126793:	[]
# Q127076:	[]
# Q54926352:	[]
# Q127213:	[]
# Q1283714:	[]
# Q127771:	[]
# Q64225484:	[]
# Q19287541:	[]
# Q216916:	[]
# Q19403027:	[]
# Q11436:	[]
# Q7194062:	[]
# Q1882685:	[]
# Q620681:	[]
# Q1184840:	[]
# Q7978115:	[]
# Q7550889:	[]
# Q197:	[]
# Q2875704:	[]
# Q154503:	[]
# Q1949826:	[]
# Q127843:	[]
# Q61002:	[]
# Q201662:	[]
# Q127930:	[]
# Q1717246:	[]
# Q128124:	['engineer']
# Q128309:	[]
# Q133163:	[]
# Q55723238:	[]
# Q55723232:	[]
# Q55723210:	[]
# Q5199281:	[]
# Q1555833:	[]
# Q5280487:	[]
# Q19588483:	[]
# Q128393:	[]
# Q97322761:	[]
# Q128406:	[]
# Q128558:	[]
# Q128758:	[]
# Q60548032:	[]
# Q129238:	[]
# Q129286:	[]
# Q129536:	['earth scientist', 'engineer']
# Q294126:	['earth scientist', 'engineer']
# Q11699606:	['earth scientist', 'engineer']
# Q5352191:	[]
# Q108289383:	[]
# Q108289028:	[]
# Q130263:	[]
# Q130286:	[]
# Q63769412:	[]
# Q29584790:	[]
# Q29584341:	[]
# Q268626:	[]
# Q130352:	[]
# Q130693:	[]
# Q1316689:	[]
# Q130825:	[]
# Q130857:	['musician']
# Q130982:	[]
# Q131026:	[]
# Q131030:	[]
# Q370502:	[]
# Q131062:	['scientist', 'earth scientist']
# Q101244323:	['scientist', 'earth scientist']
# Q60332470:	['scientist', 'earth scientist']
# Q901402:	['scientist', 'earth scientist']
# Q131081:	[]
# Q131084:	[]
# Q131089:	[]
# Q131132:	[]
# Q131168:	[]
# Q55738940:	[]
# Q55738924:	[]
# Q131172:	[]
# Q953045:	[]
# Q1480529:	[]
# Q266328:	[]
# Q23009459:	[]
# Q131186:	[]
# Q29881373:	[]
# Q131201:	[]
# Q219416:	[]
# Q131212:	[]
# Q985394:	[]
# Q166142:	[]
# Q956238:	[]
# Q131221:	[]
# Q131327:	[]
# Q2588141:	[]
# Q1404808:	[]
# Q1261842:	[]
# Q131359:	[]
# Q131375:	[]
# Q18703581:	[]
# Q131427:	[]
# Q131479:	[]
# Q131505:	[]
# Q131508:	[]
# Q131524:	['businessperson']
# Q131539:	[]
# Q131572:	[]
# Q706601:	[]
# Q131647:	[]
# Q28886448:	[]
# Q18536132:	[]
# Q131734:	[]
# Q1252971:	[]
# Q131746:	[]
# Q2151963:	[]
# Q131767:	['politician']
# Q15903946:	[]
# Q11247470:	[]
# Q1221126:	[]
# Q132050:	['politician']
# Q132116:	[]
# Q132151:	[]
# Q132518:	[]
# Q132603:	[]
# Q132821:	[]
# Q149086:	[]
# Q74948922:	[]
# Q4:	[]
# Q2956046:	[]
# Q3537517:	[]
# Q65757353:	[]
# Q16688120:	[]
# Q132851:	['military personnel']
# Q337902:	['military personnel']
# Q4319062:	['military personnel']
# Q133004:	[]
# Q177626:	[]
# Q1800545:	[]
# Q133036:	[]
# Q2875163:	[]
# Q271588:	[]
# Q911059:	[]
# Q10354139:	[]
# Q133080:	[]
# Q133201:	[]
# Q133215:	[]
# Q133485:	[]
# Q108290376:	[]
# Q108289406:	[]
# Q133683:	[]
# Q133744:	[]
# Q29584817:	[]
# Q29584355:	[]
# Q29584228:	[]
# Q133805:	[]
# Q134147:	[]
# Q134154:	[]
# Q22988604:	[]
# Q134307:	[]
# Q134313:	[]
# Q134435:	[]
# Q134456:	[]
# Q134783:	[]
# Q134995:	[]
# Q16387:	[]
# Q135450:	[]
# Q548320:	[]
# Q2566598:	[]
# Q16824629:	[]
# Q136578:	['military personnel']
# Q136822:	[]
# Q9166713:	[]
# Q136851:	[]
# Q137350:	[]
# Q1364673:	[]
# Q137378:	[]
# Q138365:	['activist']
# Q4887411:	['activist']
# Q8359428:	['activist']
# Q3290825:	[]
# Q138679:	[]
# Q138775:	[]
# Q7574898:	[]
# Q161837:	[]
# Q138796:	[]
# ...
# cfd707eb52a3c2b342dc46b312b25bd7:	[]
# cfebb4c97b5513ba3106a82b55c97b07:	[]
# d0bf4fd2288918eb44af07ed8fd10ca0:	[]
# d0c272770613206ee4cc82b3581b9cff:	[]
# d11026a2d64bd57d47d9f736f47188cc:	[]
# d12990f951b08f983c88291ea2219f0c:	[]
# d16f7c5b5fa365e8f5be5b439bd8b77a:	[]
# d219ef0aa199f6703b66e3e8253356e5:	[]
# d22b56785a132f1bb7f500400305a34e:	[]
# d271fe7321c44cf36678966b910924b3:	[]
# d2f3898ee7f376ddb5674974a83d5c32:	[]
# d3507075daafce2e8bdf7aa4f1118cd2:	[]
# d3f489739689f4db5f37ca14849766a4:	[]
# d58d4bcebd7a05b5fa2fbe31f733c9a9:	[]
# d67d05f6eab10b952aafc8887e15c517:	[]
# d726177a96f23d3a201afdb65aaf163c:	[]
# d7524fafffe1ad2ab7458a6fbccaebca:	[]
# d803e66326720f5b9755a83b348ad6a8:	[]
# d83dc35c16bc87278b55b8fbcbc87909:	[]
# d86000620406c96a4de7b947a883958a:	[]
# d8ae24644828152103c6bef011b0a6ed:	[]
# d8b7c67270f6cf151ee8e5656a19b76e:	[]
# d8ea3322a9f38d92ef6eaadb551958c8:	[]
# d913af035f875f9e9b92eec3f6b52489:	[]
# d9a6ac414e63959ce63abddd3297410d:	[]
# dc3fed97828b9426ffbbeb9d25f436c2:	[]
# dc473320d24f4ddb70223a34ef820d2c:	[]
# dd1814db3f121f0e01935cb09541ca8e:	[]
# dd694c8278ee9bb335a8f27958f910cd:	[]
# dd8f9b6ef2da60657825bd05a4a1c9e2:	[]
# dda321fbee138f2c556f1aa71ccb3835:	[]
# de07a5d2653e981b929f22db71b3a7df:	[]
# de23ab3cc5f34662cdf879d4ad7d6c0c:	[]
# de436f3c5611f03778a3b31f18ad1dd7:	[]
# de644fce730cc053f5d067ddc9f1488e:	[]
# dff149f8037b6ae7de1555f1876163e8:	[]
# e0206fe5230356b3b6d9f9c15cc8bd0b:	[]
# e0391e2bce3a642288262356ba51d840:	[]
# e059c996aeeb287c3c309978d6b33aff:	[]
# e08fdca32fce4212572f7bcdc63fd084:	[]
# e154d059f34e710102ab0a47d0df10c1:	[]
# e1a59dc0d5bd260b3984a81009cccff8:	[]
# e1b947af0abccf1e48fa4a470ef98710:	[]
# e30fb803638b30bbaf4c1bbbcc4d75ef:	[]
# e334f6aa3b24b92d2e943776d351a6b0:	[]
# e37534b1fa2cd45cad2f3ebac56eab28:	[]
# e37ae60b1cc221785e4eda684c4a7ade:	[]
# e3e4aaaeec2ea923cbac4cf5f23c2ed2:	[]
# e3e4d7073711db84e4fb4d6893758fcc:	[]
# e435e68ef7bf223923b54c8f2717b1fe:	[]
# e46bc9ec371c0dbde97a0c94b408e2c1:	[]
# e4b67be0ad6ae4a79552615a7c316ff1:	[]
# e50a08a2292288c7a9c5924b0d2da06a:	[]
# e656043a4793337218290b46e453469c:	[]
# e6f5b4b4b6b97387532abf43088ae13a:	[]
# e73d10d5acf8378ad57478a818bf2d22:	[]
# e8418f8b4a0d48680e79280f725ff915:	[]
# e8a0f79f090f21c012026970fc538601:	[]
# e8fca2d43fb21a63c190e1194f699db1:	[]
# e9d9075c82fa8fddac7530bea1caa5ea:	[]
# ea57f7d7f2f6e4ff0c709e1b0ff4e459:	[]
# eb45d5c2583b360bb5d3188cf1040e0f:	[]
# eb5cbf1500d86690a24a21fa4f54ed00:	[]
# eba8e203a0830c1979a94ab33536b33e:	[]
# ec10ccd7e1a5ecd1f90f8fc5137fc52b:	[]
# ec25d7c9e5159bfb876ebd7acb04347d:	[]
# ec605952fbf7d97ba394def6e57ddfd1:	[]
# ede48ebc6f30fb74c508ee4a513a94ec:	[]
# ee6668586015af3e8505c90742096b84:	[]
# ee92a787b2b4b8737cbc6146d57ecc22:	[]
# eed0e2be4bd9cf5f197b13863b1fe263:	[]
# ef8912b125ee032d3dc86d625c750473:	[]
# f00109add5a0f5ed0cc971339f36318d:	[]
# f0fdd5edccd542478377608946f7590e:	[]
# f2c3b82cd335d8babaaa68a547cc26ca:	[]
# f2e7eba68e5fac0fe00901627d86822d:	[]
# f334b33c355c4b60256c240bf5545b17:	[]
# f33ede674fc9e565b8ffd980171149c0:	[]
# f3c13850224650bbf8efefa9f95bcc45:	[]
# f3c54036fe2f73df5222ecc448708aad:	[]
# f3c8850a8ad0796da7f486d8b685fd42:	[]
# f410c1ce822aad3ff5ca335c24da1ab5:	[]
# f43bb753bc8a7bba26313fb227353f8f:	[]
# f4d1f5b34ff160c048fc1c65d99dacdf:	[]
# f55239baa8888adde4089268042557c1:	[]
# f56329a3f5f32b4f97f1b432703a1929:	[]
# f5afc051974217b23e5035d577322796:	[]
# f5b9ede36418858665b5af69957f959e:	[]
# f6804f29a94eadfb34ab2b1dacde7690:	[]
# f70d2ae720a2e3d8265d6a23971d3bb0:	[]
# f7341a66172642114d71af8c7aa94120:	[]
# f75648a380c46fef4f00476e5e83d6fe:	[]
# f770b3c6027deffe68ff92afd6688e22:	[]
# f7a8b43ecc1e66170c45f3a2e0eac72e:	[]
# f7c4ac99c29a43a75d76580ad7e7cfe2:	[]
# f81408cacc0043b0ccae086728495e67:	[]
# f87eecf68a67c5e424bc77d0b240c8a2:	[]
# f8c57e6f27d83bb4213442bb6895f30b:	[]
# f9663ab38fa85e503e2f85b0db947bcb:	[]
# f96e735d2b9249c0c36f5bb6cb817ead:	[]
# f96e86192d699776b22960e91a0aa0a8:	[]
# f9e80ddec2094253d31685e822e22a56:	[]
# fa449e8481dc11db81acbfeef5e10315:	[]
# fadc30cb57617134c7f648d966c25c05:	[]
# fb4e261dab5da4f4a4d826229f15852c:	[]
# fbed711f26e3331dcbe57c57341a5fe4:	[]
# fc0981314e33c8894168a23157e6d0f3:	[]
# fc52cbb4f7b72de6c0b5f0de34cb13bf:	[]
# fc995fb600de41595b7c3e7e1eac5a79:	[]
# fd14a07a054205e98d55a88b2339d49c:	[]
# fd4e9d764fd91f4f6b63cbe7b52bd33f:	[]
# fe6170af0496e65d93b781e2e352cb48:	[]
# ff5d50ebab2dbe0d4742f76ef2bc0b92:	[]
# ff9c3efdccad2cddc3ddaeb5107fb23d:	[]
# ffdc46194e24d05b4c3eca3b48f4af50:	[]
# ffdd3f5d071d6c9b4e68b27398311b9e:	[]
# 00cde86f60fb59fc68d7a87d4061b23b:	[]
# 012655a6f945ba1e8af94e86cd2776f9:	[]
# 01be07ff36a049706d874deee0e6fa36:	[]
# 01c455cd63ff698d755963221512084d:	[]
# 01f75962e2b48894c3887fd058f2d95e:	[]
# 0224ffad90a632ae156ee5c56cd7ba4f:	[]
# 022aafb5a8c75411c0bcb1fb4af1b5b5:	[]
# 022ff35904429390bc53f43fd35ea221:	[]
# 026533f99931fa30287d826119a298b2:	[]
# 02c8d12904a5477b5ba16bbb5d3bf9e2:	[]
# 031e7887ae4f0f407a6d80ac4b9b7c33:	[]
# 03637eadcb9bb2bfc1b0d4e6ed003ae4:	[]
# 03777f3c5bd4ae8812fc6ac5e97bd5b3:	[]
# 037aba000fb9c1938c8eeb8e1c63e9cf:	[]
# 043ad75e6867eeec51c2f56a4e88d63a:	[]
# 0535b8a2682e7af16d4dec96e259201a:	[]
# 05ae436fdf9dcdf61e520c8d757d1d17:	[]
# 069bf1bc86e39e34c244b42180347fdd:	[]
# 06b7e4bac84b7672ab680121637dff72:	[]
# 078cf234e610a12c0b3d1ef387d23a8e:	[]
# 07c7f1b5486e9644b19f2c385daf3e28:	[]
# 07f6baa6f23f47bb331a53c323590b6e:	[]
# 08acaebf24cb5a5e5172b4da74df0e78:	[]
# 08cc1fbbc2b0b14e23c8a3aca70541a4:	[]
# 08d01ec57299cb970ca02d4bd13d1420:	[]
# 095e87cb15ed10540a15eecbdb39811e:	[]
# 0a04adbcce463fe3ae9896707edb6c89:	[]
# 0a5fe13522aefaf9bcbdfd19eaf31c78:	[]
# 0a899af6567dce5be37f40e889f6cb68:	[]
# 0aa0f59beff763c778529d83ccdedee7:	[]
# 0b283791ef12e60628c236457e07902d:	[]
# 0bc8389513399228a0174f84ff897018:	[]
# 0bfc8a3a124b6164b0f6912064a9fbb2:	[]
# 0c09ec5e83900c133ea50858821e793d:	[]
# 0c65251f8c766a2d1940aca74dde70d8:	[]
# 0c7097662e469f98d9702670c2fc2239:	[]
# 0cb6d89a99d250b24ebf26e9da764ae0:	[]
# 0db902eaf3cbaa2ba559d77e578c05a8:	[]
# 0e3666948cb6f9ca23e94a5bff5729a8:	[]
# 0edc0fcb4e696e779f4111fd9bf93fdc:	[]
# 0f3049cb8953b1a6e20e3952ecde6bed:	[]
# 0f5aa102b7bfdb03d5af045d0fc366c6:	[]
# 0fd0941ddef6ce69ad4a49ebdca5c6f6:	[]
# 1039db7f0e05a2c8c1d504d7bc4ed607:	[]
# 1072e3526c2d44d06cb7a44da47591db:	[]
# 10a2c2b5db4932c32076cfc349f2480f:	[]
# 10b4c87b996725c5971fb631e5a308fb:	[]
# 10bd1061ea2c3c4ce41dc2e93604f49c:	[]
# 10c59fdc491e90eedfd3e85e96450b55:	[]
# 112708cdeab18b24992796a123702326:	[]
# 11fa6e2a106de0ff05e12299ea74a3b6:	[]
# 1248940d94085a0c63f9cdf3d76bb6f7:	[]
# 138e7689ca04ac5643228b014880a74d:	[]
# 13f0cba49b41b9d0f32e906510d4c406:	[]
# 14784f055397f19889ba770576fd4eb1:	[]
# 148a7afca52c07866d28bea49748e937:	[]
# 14a771ace3263ff9a7386b918b5a5b2c:	[]
# 14bf5e855c939bb5627b90ab785d253c:	[]
# 1672e8d95ae7de2137fc3a7767ab0a2c:	[]
# 16d60f30b6896f64e6d79652bf79b5a6:	[]
# 1841c52c06daf3b03e98a00e1559b59a:	[]
# 18724dc8c2ba8cbbc1d2ee58ae2d3d9b:	[]
# 189455eace31f4ca46703a306d157613:	[]
# 1908eb27ca10737126a57732c9d6adb3:	[]
# 19585880081716aca7ddb06bce36220c:	[]
# 1a35af79e346f159d978587ec5c332b8:	[]
# 1a3ffe9ebdde17c1245991c465de5186:	[]
# 1ac487f21f331f59c71b415e80c4bca4:	[]
# 1add687f32088e0554f27d431dcebd70:	[]
# 1ae0fe941c5dfa8c4382d01107236ead:	[]
# 1af2cc7d66df8531b359c30a05bb618a:	[]
# 1bbd7ff6edc787bd63a5c04ad6e292f6:	[]
# 1c3f4473431dcce3032d0a213413a35c:	[]
# 1c7ed97053e57fc8f74df00c66e95198:	[]
# 1c9a31ece2880a93a6c1ec35cb473c4f:	[]
# 1cac8b9deecdd33feb08a8ada6b34371:	[]
# 1cfbf04bf9fad8797806b5549cf8b112:	[]
# 1d69a131e5bda69611c88c4cb4ab2610:	[]
# 1e650741f30c7a14d625dcc43de92c27:	[]
# 1ea9c6370f3d71076ff1da9fcc05b948:	[]
# 1eaa0c2397645f5aa34d3f675d0cd60a:	[]
# 1f057d495073e1aab75a506d6e93b61f:	[]
# 1f2305c4bbca4da37208f993774bda0f:	[]
# 1f3e6ca707d9b2834aa3c176200f960c:	[]
# 1f7237fa9568b284ba8529a066fe53d4:	[]
# 1fa70d07fe4ef722b3d67a10c36f66de:	[]
# 20a40b3d26f2d9636f2551c28da728d2:	[]
# 20ec8487b2b0fe68b7db6ce9b9053f56:	[]
# 214b9c5103faa8b059441104781f7945:	[]
# 217d152920288d2a74112bbe1ff458c7:	[]
# 2199b89c2e857ca1159375c8de1bf12a:	[]
# 21ce6c3397d17f6f9a894bf8a835504b:	[]
# 220f452120cc9e2e3c7b4399c6869ef5:	[]
# 2211c777f4641b76c6927d47c9c3be75:	[]
# 226f18e89352db193db4343f1c9d8002:	[]
# 22a4805852779161364efa934819d61d:	[]
# 22a88075f9de0cc34627f17343b37b44:	[]
# 23ac1ebe2c8f2f18649e3bbc4174c6df:	[]
# 23e6f12a900d9bf3598e63f2747663c0:	[]
# 24a1d211d07704e56022f7768736667e:	[]
# 24ea3e9cb28055397beb6d43a6556d27:	[]
# 27c4f4f4efeea0571acad00e35bcfbd4:	[]
# 2894c435ed27ff7225c70af8b8fbda16:	[]
# 28b853a4abc33b8cafa9cac978770a94:	[]
# 291b0405aa965a58605621e7d572f944:	[]
# 2a5c44a617dfec46de2e2cab0f4275a4:	[]
# 2a9a6593641de6950c7e28c69b9db20b:	[]
# 2abe607d2ebd8cc4ad5879eb69e5aa6a:	[]
# 2b151424134fa02426f79cc3b6941740:	[]
# 2b4c27bed1d6cd2e85f42c3dc28a33c9:	[]
# 2d247fc9afa2acb4834b329582482de6:	[]
# 2d83003e150dabca0eabd783de67942e:	[]
# 2dfae1f5fc02fbf0a5f00d92fcf77af0:	[]
# 2dfce2a17d726625861a970f2fa0f287:	[]
# 2ea4c8e8dcf056c30b9b66804f7d679a:	[]
# 2f9215ba5c3145cedff36a88734f6bab:	[]
# 2f9ee652abefc6eed91903fa138b42fe:	[]
# 2fdb7f0e1157f9c60ef000682abd92e7:	[]
# 305ebf5c1907deda7100d471cae5693c:	[]
# 31d79e991e558c86f8d1fb069e74c732:	[]
# 3258730874b8f41831f9437f8619b5d2:	[]
# 332a5ad9fa2f5b64f342671664ed2746:	[]
# 34508b777f430aefd051c691d10899fb:	[]
# 346de337a31a2d12ad3d32afa95eaac1:	[]
# 34a2ca4fdfab72134b0dc5f6275c3625:	[]
# 34cc1124a50544e0a3d3aa40214f6125:	[]
# 3559a426769871ce30a86e5f585be01b:	[]
# 36240d14fcbf2787b186e250cd6eab7e:	[]
# 366964ed915fd015547605647f4549f4:	[]
# 37f08fa56b3e986e0f71694e73c3fce9:	[]
# 381ae948beb23f518fdb93ea2eded44d:	[]
# 3994bb2eac6ed955e98e3d5e0adf6e5a:	[]
# 3a2f5e928318866dfe4d6b7383cc078c:	[]
# 3a609f9b3420c4f96f460be32dc17117:	[]
# 3ae77a7f9f309dbe76aa5270d568670f:	[]
# 3b09e030fb1a8bf691285d266eedc57e:	[]
# 3b424eac2569bfea17acd429712f9121:	[]
# 3be35a2738590e49e922aa0249a64d13:	[]
# 3c9572746ebe70e070ffb239c6ad9e16:	[]
# 3cd38f124eb4f659230058772d903384:	[]
# 3d02f02c0fb48ce00c64837f012bf055:	[]
# 3d64ef94e9c996fff32dbe6f459bf304:	[]
# 3eece801df40020ed020869bd7839472:	[]
# 3f1c5ed13b6b43adabd59f1028aeb489:	[]
# 3f51b75e54d6c5b2d679240251c7dbe4:	[]
# 3f7ebf1ad8ed0718982537c6774d2d6c:	[]
# 3fa21ec52ceadfc4b9b0a234cace5ce5:	[]
# 40471788efaead9b3d22c4f195274060:	[]
# 41820cdb454bc35bec37b87563b4a35c:	[]
# 41f95ab2b54c54b5764bc3d6af4c6129:	[]
# 427a319a041770d004cf7566aa12abee:	[]
# 432a83cb688c2c66b99477712eee0b09:	[]
# 43bc18fb325d21dc5ef1f630c129fa1c:	[]
# 43c64f42b415a702df303912cee8fcd9:	[]
# 44b7e46bf6b159645a3538c062a6b04d:	[]
# 45bf68463649ed3bf39d97dc96992612:	[]
# 45c6a9ab798be751c987df3ae6e8881d:	[]
# 460b7941710a55fae4448d2d7eb07bc0:	[]
# 460c82738bc04c3be444314c8b66603f:	[]
# 46475bc73b2397fd476c7fa6f885af95:	[]
# 46f40d4052a5f588911dc4c26391b4ea:	[]
# 47b98dc61d051e4f41cc1a4c824c0e92:	[]
# 47bf80f94499275bbd46a40f01d557b8:	[]
# 47c70abf1ced03eaca927c78a898e636:	[]
# 4870d79f0e074e609cfda734b89d1155:	[]
# 48785846bba2ca3d6977d13b5abfeccd:	[]
# 4900d987c62eb401a72aaa100c43ad64:	[]
# 49ae40653f72c8e55c4c954d28e6642d:	[]
# 49b3f71dd550595c8ae81b6c841cd68e:	[]
# 4a00ab307e42b3a9e4faba2b8bf3c2a5:	[]
# 4a3684d45327a3d583473f6162c6fccf:	[]
# 4ad98de4dcf1919dfe6f5d0e5b43af28:	[]
# 4ae3cf60d28b40e9c683e3ed114bda54:	[]
# 4b277825ef017a433a407f535ecc8db0:	[]
# 4bb40900d02947a8317397239a8b1b77:	[]
# 4be4d2032b07750449415d9ba1e911fc:	[]
# 4cfed4addb5816ce77b4f3a01b5c490b:	[]
# 4d94115930f77dad20fac04e4947eedc:	[]
# 4f362d143894d2a00fd058d57b23a42a:	[]
# 50205981c319c1779c750103a27cd510:	[]
# 502ade50e2bc7cddc9b9d282f02cf3a5:	[]
# 50f9a4379fe913ff454fe9b0d50cb7ac:	[]
# 5100341a77900266a322acd75a310904:	[]
# 510994128d449e029db5bab96d743826:	[]
# 510becb415d3414df95c4b62cd473452:	[]
# 51c181207f002ab3f789195ed6ccc490:	[]
# 522dc381b292827f241fc2bd6ba557ff:	[]
# 545c651a87de3911815b31abbfa19b9e:	[]
# 554a89f3cd8a36a99c7af554bf1bea64:	[]
# 5587068cef64c702784be70c8f7c2822:	[]
# 56656e89b88649e39346ee620b657ac1:	[]
# 56d8c04775b84ff523aff80d02d5996c:	[]
# 56edcd99d28de1300025faf929d7ef5a:	[]
# 570264971bbb20891fdf36cead778d9e:	[]
# 57c3925415f7783838c5efec35a11d06:	[]
# 584b3d1089b1bbe7953eeaa81551d01d:	[]
# 589d9385e4dd872dbe48f5448ff49c59:	[]
# 58a655687fb1fc0e9b0817c35dc80a02:	[]
# 58b53c5f5b730d6f5e50a024c9cfda02:	[]
# 5984b4423c1dab8bfffce2c8684be117:	[]
# 5a4ef04789a578581e552efd86cbd79c:	[]
# 5a8d6ea589d3056c1dcab354593a439b:	[]
# 5ad3022df5f95cc3340f452eb8a9a247:	[]
# 5b518c332ea4cbbebdf072d91b763bdf:	[]
# 5bbdad5c06894530c283e22195ab5c54:	[]
# 5bd9e9561e3583e1e00a1ae707789e5c:	[]
# 5c5df07dd96220920f52870ab50b87e0:	[]
# 5c72a21641778503b886beba48121a6d:	[]
# 5c78bddb5a7a129e0aff5b50b2916f0d:	[]
# 5e24937b83ef605687ddfadbf4bcdd4f:	[]
# 5ed289ee7726ce45d5429480e27b876f:	[]
# 5fe1937490f301a09c896f295009bef1:	[]
# 609b33f73ff4781bfa7cb39cf07d8e5f:	[]
# 60a759b8c7537f076625751e06b04d55:	[]
# 60c52b72c2a98959757be9f54cc737b1:	[]
# 611c83a4cf411060e73d8edb524e76c7:	[]
# 62452116f3c56745593a9716d44fd6ea:	[]
# 630aa3b1de1d8d3dfe38982cc319219c:	[]
# 6384b272808fb51ba7644c4ab03ac146:	[]
# 63cf0b09e6a44c1090a0b8c8c319b909:	[]
# 63ebf100251019e944412cf6ca0f4d77:	[]
# 644d13a1d570b034eb8377dd7d3e6ba5:	[]
# 648a3fe474b193e1109567fbcdfcf287:	[]
# 648ee2c8a3c1bc430cf2500074469617:	[]
# 64bf5ae732f2210f16619596606b453a:	[]
# 6595fb60229d63a57e9a5eb16fbf91af:	[]
# 65fe30be24e5c9da437667d63b0041c8:	[]
# 667acc1c8336142058df8a7de567f171:	[]
# 66cd11abfa8f3eb8f9d3fa38c007d149:	[]
# 676cf93c7bba45e698404adf52307f45:	[]
# 678a4e71cb19c3b5b915a2bcdc915243:	[]
# 67ada572acf7734cb4d50bcde8d8bbba:	[]
# 68096914b4b239e1ffe5ea5fbb80d748:	[]
# 6819843b6c8e3db4873d045b6eae0127:	[]
# 683623a5cf3d7b179d9648c4b6aa2c0d:	[]
# 68a5e3f2eb1e944f68aaa01ed020ee76:	[]
# 6a3b782dd6951f73a7a232c193bfe51a:	[]
# 6b7b00a44467554e0c151a2a9d690acd:	[]
# 6bfc21e33cf2e01917871caf2eacec75:	[]
# 6c0bb24afd1714115315753fb550434f:	[]
# 6c7af258c51d70ab683c367d9556dccf:	[]
# 6c9725961b48bd541009d220e31fd19e:	[]
# 6c9f76bceefa63807ac4936973846ec0:	[]
# 6cd959875419027e72dcc87619daa310:	[]
# 6d46b13805ecbedcfaa6beeb4cd2ef94:	[]
# 6d69282bc14a578d63faeb9091496625:	[]
# 6dd1ad6a4a3a47ad58113423ae5c1469:	[]
# 6e29cba5d42566d6cd26a4c78000360f:	[]
# 6e89246cf6648162d3b083751d24e738:	[]
# 6ebccc825f2e58f4c2a287b6c73b2828:	[]
# 6ec3dc98a220eed4ab7d500b46206cfc:	[]
# 6efb86b636c38a1a825705febf8e4fe2:	[]
# 6fb1cc80ce72dea2c688e6789bbc3ad1:	[]
# 6fd17fa8f134d19122e1a24ea9faebb6:	[]
# 70a898d1d44159b73c2fd80a536179a2:	[]
# 70ccbf722ec7c44f5b17e236b7f02106:	[]
# 7125fa6b0b420469a65fd5bb241528db:	[]
# 71b62a3a60802f7b50faaa41933c4ee4:	[]
# 71cf20a00a4bbe51a58791420bf6d725:	[]
# 723d7f7cba96142b2d33b6fab0debd38:	[]
# 72e4a8d58feb940f6d0034e1e0cea0e9:	[]
# 72f06b04a5d4e9917a21ff771a3ed2d7:	[]
# 73e8a37a0497783c1de10e68198798b2:	[]
# 7434cb82244f043ba50bf55f006ddc07:	[]
# 750c0fa616ddfb04cc493099fa34a300:	[]
# 75a7c1135bc5d6a15b0b28dda5bb041c:	[]
# 75ed5445b4bc004b3ea51da3b0c6429b:	[]
# 7734eec2d6c808a30101458689b1ad72:	[]
# 7851fd2012b83e0b5caff675e0230492:	[]
# 78ad3c1f5628f61c807e6808711f787d:	[]
# 7989885c15c21d18dec41a1b2d2612d0:	[]
# 79d09b17b46303dc1596f57c6b15af07:	[]
# 79d8c0e7b0f24e35389ecc8b3584ebfb:	[]
# 7a1a3baa03acff7580d6f14d80df37f9:	[]
# 7a21d7b9f2f11a8d8b459a4dfb235736:	[]
# 7a31990cc3de8c190141dbb0b834ce7b:	[]
# 7a5cba516fd615bc16ac55b886741663:	[]
# 7af68afd7a1163b915721309114fc1b8:	[]
# 7b97ae50fd11f1226d21fbb3ec112bea:	[]
# 7c2c28503d4de6e1c3c7223269444f6a:	[]
# 7ce4a4ab6984838873ec65e6f843a7a1:	[]
# 7d5ebb6d25dcd4420c22626110a53ed6:	[]
# 7de23eba16b3ce31afdc6b9602c7062a:	[]
# 7e0494d5cb64eb82db89ee7c827545c4:	[]
# 7e80b11633880c2863f5e97a463e5832:	[]
# 7e86c394d8f713ac366b4948e226a625:	[]
# 7ee43dac9c7bf2c20f8ea1709655e95b:	[]
# 7f68d028ca1ba8080282ea674ed8fa92:	[]
# 7ff4be1dc32b4cb4ae6695aa9791c71a:	[]
#
# Stats of occurrences:
# politician:	614 occurences.
# artist:	512 occurences.
# civil servant:	488 occurences.
# businessperson:	432 occurences.
# musician:	399 occurences.
# health professional:	377 occurences.
# athlete:	353 occurences.
# humanities scholar:	331 occurences.
# military personnel:	331 occurences.
# clergyperson:	266 occurences.
# scientist:	265 occurences.
# educator:	258 occurences.
# biologist:	243 occurences.
# jurist:	215 occurences.
# performing artist:	211 occurences.
# writer:	208 occurences.
# engineer:	205 occurences.
# sportsperson (non-athlete):	205 occurences.
# media professional:	177 occurences.
# activist:	160 occurences.
# social scientist:	159 occurences.
# designer:	131 occurences.
# transportation occupation:	128 occurences.
# earth scientist:	105 occurences.
# agricultural worker:	91 occurences.
# journalist:	80 occurences.
# linguist:	58 occurences.
# information professional:	53 occurences.
# physicist:	42 occurences.
# chemist:	40 occurences.
# mathematician:	40 occurences.
# computer scientist:	26 occurences.
